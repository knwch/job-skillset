# %%
# Import dependencies
import requests
import json
import pandas as pd
import timeß

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4, ensure_ascii=False)
    print(text)

# %%
# get the API KEY here: https://developers.google.com/custom-search/v1/overview
API_KEY = "APIKEY"

# get your Search Engine ID on your CSE control panel
SEARCH_ENGINE_ID = "CSEID"

COUNT = 0

# %% [markdown]
# # Check Requests

# %%
print('COUNT', COUNT, '/100')
# Out:
# COUNT 0 /100

# %% [markdown]
# ## Test API

# %%
# the search query you want
query = "ทันตแพทย์"

# using the first page
page = 1

# constructing the URL
# doc: https://developers.google.com/custom-search/v1/using_rest
# calculating start, (page=2) => (start=11), (page=3) => (start=21)
start = (page - 1) * 10 + 1
url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}&start={start}"

# %%
# make the API request
data = requests.get(url).json()
COUNT = COUNT + 1

# %%
# get the result items
search_items = data.get("items")

# iterate over 10 results found
for i, search_item in enumerate(search_items, start=1):
    
    # get the page title
    cse_title = search_item.get("title")
    
    # page snippet
    cse_description = search_item.get("snippet")
    
    # extract the page url
    cse_url = search_item.get("link")
    
    if 'cse_image' in search_item.get("pagemap"):
        cse_image = search_item.get("pagemap").get("cse_image")[0].get("src")
    else:
        cse_image = ''

    meta_title = search_item.get("pagemap").get("metatags")[0].get("og:title", "")

    meta_description = search_item.get("pagemap").get("metatags")[0].get("og:description", "")

    meta_url = search_item.get("pagemap").get("metatags")[0].get("og:url", "")
    
    meta_image = search_item.get("pagemap").get("metatags")[0].get("og:image", "")
    
    meta_site_name = search_item.get("pagemap").get("metatags")[0].get("og:site_name", "")
    
    meta_type = search_item.get("pagemap").get("metatags")[0].get("og:type", "")
    
    udemy_category = search_item.get("pagemap").get("metatags")[0].get("udemy_com:category", "")
    
    udemy_instructor = search_item.get("pagemap").get("metatags")[0].get("udemy_com:instructor", "")
    
    udemy_price = search_item.get("pagemap").get("metatags")[0].get("udemy_com:price", "")
        
    # print the results
    print("="*10, f"Result #{i+start-1}", "="*10)
    print("cse_title:", cse_title)
    print("cse_description:", cse_description)
    print("cse_url:", cse_url)
    print("cse_image:", cse_image)
    
    print("meta_title:", meta_title)
    print("meta_description:", meta_description)
    print("meta_url:", meta_url)
    print("meta_image:", meta_image)
    print("meta_site_name:", meta_site_name)
    print("meta_type:", meta_type)
    print("udemy_category:", udemy_category)
    print("udemy_instructor:", udemy_instructor)
    print("udemy_price:", udemy_price, "\n")
# Out:
# ========== Result #1 ==========
# cse_title: ช่องปากและฟันตรวจเองได้ง่ายนิดเดียว ฉบับทันตแพทย์สอน | Practicing for ...
# cse_description: 28 ต.ค. 2020 ... ช่องปากและฟันตรวจเองได้ง่ายนิดเดียว ฉบับทันตแพทย์สอน | Practicing for basic oral
# and teeth examination: By dentist. CMU035. สุขภาพและการแพทย์.
# cse_url: https://thaimooc.org/course/THAIMOOC%3A%3Acourse--v1%3ACMU-CMU035-2020
# cse_image: https://lms.thaimooc.org/asset-v1:CMU+CMU035+2020+type@asset+block@Banner.jpg
# meta_title:
# meta_description:
# meta_url:
# meta_image:
# meta_site_name:
# meta_type:
# udemy_category:
# udemy_instructor:
# udemy_price:
#
# ========== Result #2 ==========
# cse_title: CHULA MOOC | คอร์สเรียนออนไลน์ฟรี สังคมผู้สูงอายุและการดูแลสุขภาพ ...
# cse_description: ผู้ช่วยศาสตราจารย์ ทันตแพทย์หญิง ดร.อรพินท์ โคมิน และคณะ.
# cse_url: https://mooc.chula.ac.th/courses/58
# cse_image: https://mooc.chula.ac.th/favicon.png?v=2
# meta_title: CHULA MOOC | คอร์สเรียนออนไลน์ฟรี สังคมผู้สูงอายุและการดูแลสุขภาพช่องปาก
# meta_description: รายวิชา Aging Society and The Oral Health Care จะนำเสนอเกี่ยวกับสภาวะการเข้าสู่ของสังคมผู้สูงอายุของประเทศไทย ความสำคัญของการเตรียมตัวรับมือของของการเข้าสู่สังคมผู้สูงอายุในฐานะบุคคลากรที่ทำงานด้านสาธารณสุข การเปลี่ยนแปลงทางกายภาพและสภาพจิตใจ ที่มีผลต่อการดูแลสุขภาพองค์รวม การเปลี่ยนแปลงของสุขสภาวะในช่องปาก การตรวจและการดูแลรักษา ในเรื่องของการให้การรักษาจะกล่าวถึงเนื้อ
# meta_url: https://mooc.chula.ac.th/courses/58
# meta_image: https://mooc.chula.ac.th/favicon.png?v=2
# meta_site_name:
# meta_type: article
# udemy_category:
# udemy_instructor:
# udemy_price:
#
# ========== Result #3 ==========
# cse_title: CHULA MOOC | คอร์สเรียนออนไลน์ฟรี สังคมผู้สูงอายุและการดูแลสุขภาพ ...
# cse_description: สังคมผู้สูงอายุและการดูแลสุขภาพช่องปาก (จุฬาฯ). 5013.1.CU. สุขภาพ. ผู้ช่วย
# ศาสตราจารย์ ทันตแพทย์หญิง ดร.อรพินท์ โคมิน และคณะ. เร็ว ๆ นี้ เต็มแล้ว ลงทะเบียนเรียน
#  ...
# cse_url: https://mooc.chula.ac.th/courses/165
# cse_image: https://mooc.chula.ac.th/favicon.png?v=2
# meta_title: CHULA MOOC | คอร์สเรียนออนไลน์ฟรี สังคมผู้สูงอายุและการดูแลสุขภาพช่องปาก (จุฬาฯ)
# meta_description: รายวิชา Aging Society and The Oral Health Care จะนำเสนอเกี่ยวกับสภาวะการเข้าสู่ของสังคมผู้สูงอายุของประเทศไทย ความสำคัญของการเตรียมตัวรับมือของของการเข้าสู่สังคมผู้สูงอายุในฐานะบุคคลากรที่ทำงานด้านสาธารณสุข การเปลี่ยนแปลงทางกายภาพและสภาพจิตใจ ที่มีผลต่อการดูแลสุขภาพองค์รวม การเปลี่ยนแปลงของสุขสภาวะในช่องปาก การตรวจและการดูแลรักษา ในเรื่องของการให้การรักษาจะกล่าวถึงเนื้อ
# meta_url: https://mooc.chula.ac.th/courses/165
# meta_image: https://mooc.chula.ac.th/favicon.png?v=2
# meta_site_name:
# meta_type: article
# udemy_category:
# udemy_instructor:
# udemy_price:

# %% [markdown]
# ---

# %% [markdown]
# ## init keywords

# %%
skill_keywords = [
"ช่างเทคนิค",
"ช่างยนต์ ช่างกลโรงงาน",
"ช่าง CNC Mold กลึง เจียระไน",
"พนักงานฝ่ายบุคคล (HR)",
"ฝึกอบรม",
"บริหารค่าจ้าง บริหารผลตอบแทน",
"สรรหาบุคลากร",
"แรงงานสัมพันธ์", 
"วิเคราะห์ธุรกิจ วิเคราะห์ข้อมูล",
"ที่ปรึกษาทางธุรกิจ",
"การเงิน",
"ธุรการ การจัดการทั่วไป",
"ประสานงานทั่วไป",
"พนักงานทำความสะอาด แม่บ้าน",
"บริหารอสังหาริมทรัพย์",
"บัญชี",
"ธุรการบัญชี",
"ภาษี",
"ตรวจสอบบัญชี",
"Call Center",
"ตรวจสอบคุณภาพ",
"วางแผนการผลิต งานควบคุมการผลิต",
"ผลิตทั่วไป",
"บริหารการผลิต",
"พัฒนาสินค้า",
"เลขานุการ เลขานุการผู้บริหาร",
"วิจัยและพัฒนาผลิตภัณฑ์",
"นักเคมี",
"เจ้าหน้าที่ห้องปฎิบัติการ (Lab)",
"นักวิทยาศาสตร์การอาหาร",
"วิศวกรไฟฟ้า อิเล็กทรอนิกส์",
"วิศวกรการผลิต วิศวกรโรงงาน",
"วิศวกรเครื่องกล",
"วิศวกรสิ่งแวดล้อม และ จป",
"วิศวกรรมอุตสาหการ",
"วิศวกรโครงการ",
"วิศวกรซ่อมบำรุง",
"วิศวกรรมเคมี",
"กราฟิกดีไซน์",
"ครีเอทีฟ",
"ออกแบบกราฟิก",
"วางกลยุทธ์การโฆษณา",
"เขียนแบบ Drawing AutoCad",
"ช่างภาพ ตัดต่อ",
"โปรแกรมเมอร์",
"Software Engineer",
"ดูแลระบบ Network",
"IT Project Manager",
"IT Support Help Desk",
"Software Tester",
"ที่ปรึกษาไอที",
"Database Administration",
"IT Security",
"System Analyst",
"นักวิทยาศาสตร์ข้อมูล",
"ดูแลเว็บไซต์ และ SEO",
"นักออกแบบ UX/UI",
"Business Analyst (BA)",
"Data Engineer",
"Front End Developer",
"Back End Developer",
"DevOps Engineer",
"IT Product Manager",
"iOS Developer",
"Android Developer",
"Scrum Master"
]

career_keywords = [
"Lawyer",
"Civil Engineer",
"Foreman",
"Architect",
"Brand and Product Management",
"Digital Marketing",
"General Marketing",
"Marketing Manager",
"Direct Marketing",
"Event Staff",
"Public Relations",
"Business Development",
"Marketing Communications",
"Nurse",
"Pharmacist",
"Medical Technology",
"Veterinary",
"Physician / Surgeon",
"Dentist",
"Teacher",
"Import Export",
"Shipping",
"Messenger",
"Executive Chauffeur",
"Salesperson",
"Sales Support",
"Customer Service",
"Telesales",
"Sales (PC)",
"Sales Engineer",
"Interpreter",
"Chef",
"Waitress",
"Batista",
"Procurement",
"Maintenance Technician",
"Electrician",
"Technician",
"Mechanical Technician",
"CNC Mold Cutting Lathe",
"HR Executive",
"Training and Deveopment",
"Compensation Management",
"Recruitment",
"Employee Relations",
"Business Analyst",
"Business and Management Consultant",
"Finance",
"Admin Staff",
"Coordinator",
"Housekeeper",
"Property Manager",
"Accounting",
"Accounting Admin",
"Tax",
"Auditor",
"Call Center",
"Quality Control",
"Production Planning and Control",
"General Production",
"Production Management",
"Product Development",
"Executive Secretary",
"Research and Development",
"Chemist",
"Laboratory Staff",
"Food Scientist",
"Electrical Engineer, Electronics",
"Manufacturing Engineer",
"Mechanical Engineer",
"Environment and Safety Engineer",
"Industrial Engineer",
"Engineering Project Manager",
"Maintenance Engineer",
"Chemical Engineer",
"Graphic Design",
"Creative",
"Graphic Design",
"Strategic Media Planning",
"AutoCad Drawings",
"Photography Editing",
"Programmer",
"Software Engineer",
"Network Administrator",
"IT Project Manager",
"Support Help Desk",
"Software Tester",
"IT Consulting",
"Database Administration",
"IT Security",
"System Analyst",
"Data Scientist",
"Web Administrator and SEO",
"UX/UI Designer",
'Business Analyst (BA)',
"Data Engineer",
"Front End Web Developer",
"Back End Developer",
"DevOps Engineer",
"Product Manager",
"iOS Developer",
"Android Developer",
"Scrum Master"
]

# %%
tech_keywords = []
df_tech_keywords = pd.read_excel('exports/Tech-Keywords.xlsx', index_col=0).reset_index()

for index in df_tech_keywords.index:
    if pd.isnull(df_tech_keywords['other_keywords'][index]):
        tech_keywords.append(df_tech_keywords['keyword'][index])
        
    else:
        tech_keywords.append(df_tech_keywords['keyword'][index]+ " OR " + df_tech_keywords['other_keywords'][index].replace(', ', ' OR '))

# %%
# tech_keywords = tech_keywords[90:]
tech_keywords
# Out:
# ['API Testing',
#  'Cloud Computing',
#  'Containerization',
#  'Data Lake',
#  'Data Pipeline',
#  'Data Warehouse',
#  'Google Adword',
#  'Google Analytics',
#  'Google PageSpeed Insights',
#  'Google Trends',
#  'Java Programming',
#  'Kotlin Programming',
#  'Mobile Testing',
#  'Operating System',
#  'Project Management',
#  'Python Programming',
#  'R Programming',
#  'Swift Programming',
#  'Swift UI',
#  'Virtualization',
#  'XML']

# %%
skill_keywords_merge = []
for i in range(len(skill_keywords)):
    skill_keywords_merge.append(skill_keywords_thai[i] + " OR " + skill_keywords[i])

# %%
career_keywords_merge = []
for i in range(len(career_keywords)):
    career_keywords_merge.append(career_keywords_thai[i] + " OR " + career_keywords[i])

# %%
career_keywords_thai = career_keywords_thai[0:100]
career_keywords_thai
# Out:
# ['พนักงานฝ่ายบุคคล (HR)',
#  'ฝึกอบรม',
#  'บริหารค่าจ้าง บริหารผลตอบแทน',
#  'สรรหาบุคลากร',
#  'แรงงานสัมพันธ์',
#  'วิเคราะห์ธุรกิจ วิเคราะห์ข้อมูล',
#  'ที่ปรึกษาทางธุรกิจ',
#  'การเงิน',
#  'ธุรการ การจัดการทั่วไป',
#  'ประสานงานทั่วไป',
#  'พนักงานทำความสะอาด แม่บ้าน',
#  'บริหารอสังหาริมทรัพย์',
#  'บัญชี',
#  'ธุรการบัญชี',
#  'ภาษี',
#  'ตรวจสอบบัญชี',
#  'Call Center',
#  'ตรวจสอบคุณภาพ',
#  'วางแผนการผลิต งานควบคุมการผลิต',
#  'ผลิตทั่วไป',
#  'บริหารการผลิต',
#  'พัฒนาสินค้า',
#  'เลขานุการ เลขานุการผู้บริหาร',
#  'วิจัยและพัฒนาผลิตภัณฑ์',
#  'นักเคมี',
#  'เจ้าหน้าที่ห้องปฎิบัติการ (Lab)',
#  'นักวิทยาศาสตร์การอาหาร',
#  'วิศวกรไฟฟ้า อิเล็กทรอนิกส์',
#  'วิศวกรการผลิต วิศวกรโรงงาน',
#  'วิศวกรเครื่องกล',
#  'วิศวกรสิ่งแวดล้อม และ จป',
#  'วิศวกรรมอุตสาหการ',
#  'วิศวกรโครงการ',
#  'วิศวกรซ่อมบำรุง',
#  'วิศวกรรมเคมี',
#  'กราฟิกดีไซน์',
#  'ครีเอทีฟ',
#  'ออกแบบกราฟิก',
#  'วางกลยุทธ์การโฆษณา',
#  'เขียนแบบ Drawing AutoCad',
#  'ช่างภาพ ตัดต่อ',
#  'โปรแกรมเมอร์',
#  'Software Engineer',
#  'ดูแลระบบ Network',
#  'IT Project Manager',
#  'IT Support Help Desk',
#  'Software Tester',
#  'ที่ปรึกษาไอที',
#  'Database Administration',
#  'IT Security',
#  'System Analyst',
#  'นักวิทยาศาสตร์ข้อมูล',
#  'ดูแลเว็บไซต์ และ SEO',
#  'นักออกแบบ UX/UI',
#  'Business Analyst (BA)',
#  'Data Engineer',
#  'Front End Developer',
#  'Back End Developer',
#  'DevOps Engineer',
#  'IT Product Manager',
#  'iOS Developer',
#  'Android Developer',
#  'Scrum Master']

# %% [markdown]
# # google cse request

# %%
df_cse = pd.DataFrame(columns = [
                        'keyword',
                        'cse_title', 
                        'cse_description', 
                        'cse_url', 
                        'cse_image', 
                        'meta_title',
                        'meta_description',
                        'meta_url',
                        'meta_image',
#                         'meta_article_published_time',
#                         'meta_article_author',
#                         'meta_author',
#                         'meta_section',
#                         'meta_tag',
                        'meta_site_name',
                        'meta_type',
                        'udemy_category',
                        'udemy_instructor',
                        'udemy_price'
                      ])

# %%
df_cse_en = pd.DataFrame(columns = [
                        'keyword',
                        'cse_title', 
                        'cse_description', 
                        'cse_url', 
                        'cse_image', 
                        'meta_title',
                        'meta_description',
                        'meta_url',
                        'meta_image',
#                         'meta_article_published_time',
#                         'meta_article_author',
#                         'meta_author',
#                         'meta_section',
#                         'meta_tag',
                        'meta_site_name',
                        'meta_type',
                        'udemy_category',
                        'udemy_instructor',
                        'udemy_price'
                      ])

# %%
for keyword in tech_keywords:
    
    query = keyword
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"
    data = requests.get(url).json()
    COUNT = COUNT + 1

    search_items = data.get("items")
    if search_items:
        for i, search_item in enumerate(search_items, start=1):
            
            ### CSE SECTION
            cse_title = search_item.get("title")
            cse_description = search_item.get("snippet")
            cse_url = search_item.get("link")
            if 'cse_image' in search_item.get("pagemap"):
                cse_image = search_item.get("pagemap").get("cse_image")[0].get("src")
            else:
                cse_image = ''
            
            ### META SECTION
            meta_title = search_item.get("pagemap").get("metatags")[0].get("og:title", "")
            meta_description = search_item.get("pagemap").get("metatags")[0].get("og:description", "")
            meta_url = search_item.get("pagemap").get("metatags")[0].get("og:url", "")
            meta_image = search_item.get("pagemap").get("metatags")[0].get("og:image", "")
            
#             meta_article_published_time = search_item.get("pagemap").get("metatags")[0].get("article:published_time", "")
#             meta_article_author = search_item.get("pagemap").get("metatags")[0].get("article:author", "")
#             meta_author = search_item.get("pagemap").get("metatags")[0].get("author", "")
#             meta_section = search_item.get("pagemap").get("metatags")[0].get("article:section", "")
#             meta_tag = search_item.get("pagemap").get("metatags")[0].get("article:tag", "")

            meta_site_name = search_item.get("pagemap").get("metatags")[0].get("og:site_name", "")
            meta_type = search_item.get("pagemap").get("metatags")[0].get("og:type", "")
            
            udemy_category = search_item.get("pagemap").get("metatags")[0].get("udemy_com:category", "")
            udemy_instructor = search_item.get("pagemap").get("metatags")[0].get("udemy_com:instructor", "")
            udemy_price = search_item.get("pagemap").get("metatags")[0].get("udemy_com:price", "")
            
#             'keyword_en':keyword.split(' OR ')[1], 
#             'keyword_th':keyword.split(' OR ')[0],
            new_row = {'keyword':keyword, 
                        'cse_title':cse_title, 
                        'cse_description':cse_description, 
                        'cse_url':cse_url, 
                        'cse_image':cse_image, 
                        'meta_title':meta_title,
                        'meta_description':meta_description,
                        'meta_url':meta_url,
                        'meta_image':meta_image,
#                         'meta_article_published_time':meta_article_published_time,
#                         'meta_article_author':meta_article_author,
#                         'meta_author':meta_author,
#                         'meta_section':meta_section,
#                         'meta_tag':meta_tag,
                        'meta_site_name':meta_site_name,
                        'meta_type':meta_type,
                        'udemy_category':udemy_category,
                        'udemy_instructor':udemy_instructor,
                        'udemy_price':udemy_price
                      }
            df_cse_en = df_cse_en.append(new_row, ignore_index=True)
    elif not search_items:
            new_row = {'keyword':keyword, 
                        'cse_title':'', 
                        'cse_description':'', 
                        'cse_url':'', 
                        'cse_image':'', 
                        'meta_title':'',
                        'meta_description':'',
                        'meta_url':'',
                        'meta_image':'',
#                         'meta_article_published_time':'',
#                         'meta_article_author':'',
#                         'meta_author':'',
#                         'meta_section':'',
#                         'meta_tag':'',
                        'meta_site_name':'',
                        'meta_type':'',
                        'udemy_category':'',
                        'udemy_instructor':'',
                        'udemy_price':''
                      }
            df_cse_en = df_cse_en.append(new_row, ignore_index=True)
    time.sleep(1)
    
df_cse_en.to_excel('exports/cse-keywords-en.xlsx', index=False)

# %%
for keyword in tech_keywords:
    
    query = keyword
    url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&cr=countryTH&q={query}"
    data = requests.get(url).json()
    COUNT = COUNT + 1

    search_items = data.get("items")
    if search_items:
        for i, search_item in enumerate(search_items, start=1):
            
            ### CSE SECTION
            cse_title = search_item.get("title")
            cse_description = search_item.get("snippet")
            cse_url = search_item.get("link")
            if 'cse_image' in search_item.get("pagemap"):
                cse_image = search_item.get("pagemap").get("cse_image")[0].get("src")
            else:
                cse_image = ''
            
            ### META SECTION
            meta_title = search_item.get("pagemap").get("metatags")[0].get("og:title", "")
            meta_description = search_item.get("pagemap").get("metatags")[0].get("og:description", "")
            meta_url = search_item.get("pagemap").get("metatags")[0].get("og:url", "")
            meta_image = search_item.get("pagemap").get("metatags")[0].get("og:image", "")
            
#             meta_article_published_time = search_item.get("pagemap").get("metatags")[0].get("article:published_time", "")
#             meta_article_author = search_item.get("pagemap").get("metatags")[0].get("article:author", "")
#             meta_author = search_item.get("pagemap").get("metatags")[0].get("author", "")
#             meta_section = search_item.get("pagemap").get("metatags")[0].get("article:section", "")
#             meta_tag = search_item.get("pagemap").get("metatags")[0].get("article:tag", "")

            meta_site_name = search_item.get("pagemap").get("metatags")[0].get("og:site_name", "")
            meta_type = search_item.get("pagemap").get("metatags")[0].get("og:type", "")
            
            udemy_category = search_item.get("pagemap").get("metatags")[0].get("udemy_com:category", "")
            udemy_instructor = search_item.get("pagemap").get("metatags")[0].get("udemy_com:instructor", "")
            udemy_price = search_item.get("pagemap").get("metatags")[0].get("udemy_com:price", "")
            
#             'keyword_en':keyword.split(' OR ')[1], 
#             'keyword_th':keyword.split(' OR ')[0],
            new_row = {'keyword':keyword, 
                        'cse_title':cse_title, 
                        'cse_description':cse_description, 
                        'cse_url':cse_url, 
                        'cse_image':cse_image, 
                        'meta_title':meta_title,
                        'meta_description':meta_description,
                        'meta_url':meta_url,
                        'meta_image':meta_image,
#                         'meta_article_published_time':meta_article_published_time,
#                         'meta_article_author':meta_article_author,
#                         'meta_author':meta_author,
#                         'meta_section':meta_section,
#                         'meta_tag':meta_tag,
                        'meta_site_name':meta_site_name,
                        'meta_type':meta_type,
                        'udemy_category':udemy_category,
                        'udemy_instructor':udemy_instructor,
                        'udemy_price':udemy_price
                      }
            df_cse = df_cse.append(new_row, ignore_index=True)
    elif not search_items:
            new_row = {'keyword':keyword, 
                        'cse_title':'', 
                        'cse_description':'', 
                        'cse_url':'', 
                        'cse_image':'', 
                        'meta_title':'',
                        'meta_description':'',
                        'meta_url':'',
                        'meta_image':'',
#                         'meta_article_published_time':'',
#                         'meta_article_author':'',
#                         'meta_author':'',
#                         'meta_section':'',
#                         'meta_tag':'',
                        'meta_site_name':'',
                        'meta_type':'',
                        'udemy_category':'',
                        'udemy_instructor':'',
                        'udemy_price':''
                      }
            df_cse = df_cse.append(new_row, ignore_index=True)
    time.sleep(1)
    
df_cse.to_excel('exports/cse-keywords.xlsx', index=False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_cse)
# Out:
#                        keyword  \
# 0                  API Testing
# 1                  API Testing
# 2                  API Testing
# 3                  API Testing
# 4                  API Testing
# 5                  API Testing
# 6                  API Testing
# 7              Cloud Computing
# 8              Cloud Computing
# 9              Cloud Computing
# 10            Containerization
# 11                   Data Lake
# 12               Data Pipeline
# 13              Data Warehouse
# 14              Data Warehouse
# 15              Data Warehouse
# 16              Data Warehouse
# 17              Data Warehouse
# 18              Data Warehouse
# 19               Google Adword
# 20               Google Adword
# 21               Google Adword
# 22               Google Adword
# 23               Google Adword
# 24               Google Adword
# 25               Google Adword
# 26               Google Adword
# 27               Google Adword
# 28               Google Adword
# 29            Google Analytics
# 30            Google Analytics
# 31            Google Analytics
# 32            Google Analytics
# 33            Google Analytics
# 34            Google Analytics
# 35            Google Analytics
# 36            Google Analytics
# 37            Google Analytics
# 38            Google Analytics
# 39   Google PageSpeed Insights
# 40               Google Trends
# 41               Google Trends
# 42               Google Trends
# 43               Google Trends
# 44               Google Trends
# 45               Google Trends
# 46               Google Trends
# 47               Google Trends
# 48               Google Trends
# 49            Java Programming
# 50            Java Programming
# 51            Java Programming
# 52            Java Programming
# 53            Java Programming
# 54            Java Programming
# 55            Java Programming
# 56            Java Programming
# 57            Java Programming
# 58            Java Programming
# 59          Kotlin Programming
# 60          Kotlin Programming
# 61          Kotlin Programming
# 62          Kotlin Programming
# 63              Mobile Testing
# 64              Mobile Testing
# 65              Mobile Testing
# 66              Mobile Testing
# 67              Mobile Testing
# 68              Mobile Testing
# 69              Mobile Testing
# 70              Mobile Testing
# 71              Mobile Testing
# 72              Mobile Testing
# 73            Operating System
# 74          Project Management
# 75          Project Management
# 76          Project Management
# 77          Project Management
# 78          Project Management
# 79          Project Management
# 80          Project Management
# 81          Project Management
# 82          Project Management
# 83          Project Management
# 84          Python Programming
# 85          Python Programming
# 86          Python Programming
# 87          Python Programming
# 88          Python Programming
# 89          Python Programming
# 90          Python Programming
# 91          Python Programming
# 92          Python Programming
# 93          Python Programming
# 94               R Programming
# 95               R Programming
# 96               R Programming
# 97               R Programming
# 98               R Programming
# 99               R Programming
# 100              R Programming
# 101              R Programming
# 102              R Programming
# 103              R Programming
# 104          Swift Programming
# 105          Swift Programming
# 106          Swift Programming
# 107          Swift Programming
# 108          Swift Programming
# 109          Swift Programming
# 110          Swift Programming
# 111                   Swift UI
# 112                   Swift UI
# 113                   Swift UI
# 114             Virtualization
# 115                        XML
# 116                        XML
#
#                                              cse_title  \
# 0    คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    คอร์สออนไลน์ "Mobile App Testing ด้วย APPIUM แ...
# 3    คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4      คอร์สออนไลน์ Jenkins CI/CD Workshop | SkillLane
# 5    คอร์สออนไลน์ สร้างร้านค้าออนไลน์ด้วย Woocommer...
# 6    คอร์สออนไลน์ฟรี บันได 3 ขั้น สู่การประยุกต์ใช้...
# 7    Cloud Technology Tools เพื่อการเรียนรู้ในศตวรร...
# 8    คอร์สปริญญาโทออนไลน์ Cyber Threats and Securit...
# 9    คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 10
# 11
# 12   คอร์สออนไลน์ ทำ Data Analytics ด้วย Power BI +...
# 13   คลังข้อมูล | Data Warehouse | Thai MOOC Directory
# 14   การจัดคลังข้อมูลเพื่อการตัดสินใจขององค์กร | Da...
# 15   ฉลาดด้วยข้อมูล ใครๆ ก็ทำได้ (คลังข้อมูลและการท...
# 16   คอร์สปริญญาโทออนไลน์ Business Intelligence ธุร...
# 17   คอร์สออนไลน์ เตรียมความพร้อมการจัดการและวิเครา...
# 18   CHULA MOOC | คอร์สเรียนออนไลน์ฟรี มหากาพย์ กลเ...
# 19    คอร์สออนไลน์ Google Ads Master Class | SkillLane
# 20   คอร์สออนไลน์ เจาะลึกการทำโฆษณา Google Adwords ...
# 21   คอร์สออนไลน์ "ADWORDS (Google Marketing Skill ...
# 22   คอร์สออนไลน์ "Banana Adwords 101" โดย วันชัย ศ...
# 23   คอร์สออนไลน์ เจาะลึกการทำโฆษณา Google Search A...
# 24   คอร์สออนไลน์ Google Ads 2018 พื้นฐานและเทคนิคก...
# 25   คอร์สออนไลน์ วุฒิบัตร Google Ads Search Certif...
# 26   คอร์สออนไลน์ "Banana Adwords 102" โดย วันชัย ศ...
# 27   คอร์สออนไลน์ "ติดอันดับ Google ด้วยตนเอง" โดย ...
# 28   ทำเว็บไซต์ให้ติดหน้าแรกบน Google ทันที ด้วย Go...
# 29   คอร์สออนไลน์ Google Analytics 101 สอนวิเคราะห์...
# 30   คอร์สออนไลน์ The Master of Google Analytics | ...
# 31   คอร์สออนไลน์ "เจาะลึก Google Analytics สำหรับม...
# 32           Data analytics for Business | FutureSkill
# 33   คอร์สออนไลน์ "เริ่มด้วย Facebook แล้วบุกด้วย W...
# 34    คอร์สออนไลน์ Google Ads Master Class | SkillLane
# 35   คอร์สออนไลน์ WordPress 101 สำหรับผู้เริ่มต้น |...
# 36   คอร์สออนไลน์ Zero to Hero มือใหม่ก็เรียนการตลา...
# 37   คอร์สออนไลน์ Excel Data Analytics เพื่อวิเคราะ...
# 38   คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวลา สอนโดยผู้เ...
# 39
# 40   คอร์สออนไลน์ "เริ่มด้วย Facebook แล้วบุกด้วย W...
# 41   คอร์สออนไลน์ สูตรลับ การตลาดแบบมืออาชีพ PROFES...
# 42   สร้างรายได้จาก Youtube ขึ้นสู้หน้าแรก Google |...
# 43    คอร์สออนไลน์ "eCommerce Trends 2016" | SkillLane
# 44   Dropship ขายของออนไลน์รายได้หลักแสนต่อเดือน ทำ...
# 45   คอร์สออนไลน์ เก่งภาษาแค่พลิกฝ่ามือ English fro...
# 46   คอร์สออนไลน์ สุดยอดเคล็ดลับ รับรายได้หลักล้าน ...
# 47   คอร์สออนไลน์ กลยุทธ์การทำกำไรในยุคดิจิตอลด้วย ...
# 48   คอร์สออนไลน์ Fast Forward Your Business | Skil...
# 49   คอร์สออนไลน์ PHP Programming (The Basic) | Ski...
# 50   คอร์สออนไลน์ การเขียนโปรแกรมเชิงวัตถุด้วยภาษา ...
# 51   คอร์สออนไลน์ฟรี เข้าใจ OOP ง่ายๆ ด้วยภาษา Java...
# 52   คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 53   คอร์สออนไลน์ Basic JavaScript for Modern Devel...
# 54   คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวลา สอนโดยผู้เ...
# 55   คอร์สออนไลน์ HTML5+CSS3 in 13 hours! พร้อมการใ...
# 56   คอร์สออนไลน์ Python from Beginner to Expert ตะ...
# 57   คอร์สออนไลน์ เรียนวิธีใช้ Excel 2016 จัดการฐาน...
# 58   คอร์สปริญญาโทออนไลน์ Business Intelligence ธุร...
# 59   คอร์สออนไลน์ เตรียมความพร้อมการจัดการและวิเครา...
# 60   คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวลา สอนโดยผู้เ...
# 61   คอร์สออนไลน์ สร้างร้านค้าออนไลน์ด้วย WooCommer...
# 62   คอร์สออนไลน์ พลังพยากรณ์ Python For Time Serie...
# 63   คอร์สออนไลน์ "Mobile App Testing ด้วย APPIUM แ...
# 64   คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 65   คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 66   คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 67   คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 68     คอร์สออนไลน์ Jenkins CI/CD Workshop | SkillLane
# 69   คอร์สออนไลน์ สร้างร้านค้าออนไลน์ด้วย Woocommer...
# 70   คอร์สออนไลน์ สร้างเว็บไซด์ด้วย ASP.NET Core MV...
# 71   คอร์สออนไลน์ Coding for All: เรียนรู้ Python |...
# 72   UX UI Design ตั้งแต่เริ่มต้นจนออกแบบ Web App S...
# 73
# 74   คอร์สออนไลน์ Project Management for Non-Projec...
# 75     Project Management การบริหารโครงการ | SkillLane
# 76   คอร์สออนไลน์ PRIMAVERA P6 เพื่อวางแผนและบริหาร...
# 77   คอร์สออนไลน์ การวางแผนและบริหารโครงการด้วย Mic...
# 78   คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวลา สอนโดยผู้เ...
# 79   คอร์สปริญญาโทออนไลน์ Agile Way of Working การท...
# 80   คอร์สออนไลน์ วางแผนทรัพยากรและควบคุมต้นทุนด้วย...
# 81                    seo title. 3333 4444 | SkillLane
# 82   คอร์สออนไลน์ Alidropship + Theme FlatSome ทำเว...
# 83   เจาะแก่น กลยุทธ์ธุรกิจค้าปลีก จากหน้าร้านสู่ออ...
# 84   UpSkill Python Programming เส้นทางสู่ Develope...
# 85   โปรแกรมไพทอนสำหรับวิทยาการข้อมูล | Python Prog...
# 86   ภาษา Python สำหรับวิทยาการข้อมูล (Fundamental ...
# 87   คอร์สออนไลน์ Coding for All: เรียนรู้ Python |...
# 88   Combo คอร์สเรียนสุดคุ้ม ! พัฒนาทักษะเพิ่มรายได...
# 89           Data analytics for Business | FutureSkill
# 90   คอร์สปริญญาโทออนไลน์ Python for Data Science ไ...
# 91   คอร์สออนไลน์ Python from Beginner to Expert ตะ...
# 92   คอร์สออนไลน์ เขียน Python เพิ่มโอกาสทำกำไรจากก...
# 93   คอร์สออนไลน์ Programming Essentials for Data S...
# 94       R Programming for Data Analysis | FutureSkill
# 95   คอร์สออนไลน์ Analytics 101 : โปรแกรม R สำหรับค...
# 96   คอร์สออนไลน์ Advanced Analytics 101: โปรแกรม R...
# 97   คอร์สออนไลน์ ทำ Data Analytics ด้วย Power BI +...
# 98   คอร์สออนไลน์ เตรียมความพร้อมการจัดการและวิเครา...
# 99   คอร์สปริญญาโทออนไลน์ Data Science Research Met...
# 100  วิเคราะห์ข้อมูลทางธุรกิจให้ตรงใจลูกค้าด้วย Bus...
# 101  วิเคราะห์ข้อมูลทางธุรกิจให้ตรงใจลูกค้าด้วย Bus...
# 102    CHULA MOOC | คอร์สเรียนออนไลน์ฟรี Survival Thai
# 103  คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 104  คอร์สออนไลน์ iOS App Dev Using Swift: Foundati...
# 105  คอร์สออนไลน์ PHP Programming (The Basic) | Ski...
# 106  คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 107  สร้าง Auto report ส่งหัวหน้า ง่ายๆ ผ่าน QlikSe...
# 108  คอร์สออนไลน์ Coding for All: เรียนรู้ Python |...
# 109  คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวลา สอนโดยผู้เ...
# 110  คอร์สออนไลน์ Excel Dashboard สำหรับวิเคราะห์ยอ...
# 111  คอร์สออนไลน์ iOS 12: เขียนแอพ iPhone จากดีไซน์...
# 112  คอร์สออนไลน์ iOS App Dev Using Swift: Foundati...
# 113  คอร์สออนไลน์ โมดิฟาย WordPress Theme อย่างไรให...
# 114
# 115  คอร์สออนไลน์ สร้าง Web Application ด้วยภาษา Ja...
# 116  คอร์สออนไลน์ เขียนแอป Android ด้วยภาษา Kotlin ...
#
#                                        cse_description  \
# 0    เรียนรู้ การทดสอบ Web, Mobile application และ ...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    เรียนรู้ การทดสอบ Web Application ระดับกลาง ด้...
# 4    ตอนที่ 40 การแสดง Unit test Report บน Jenkins....
# 5    11.6 การตั้งค่าการทดสอบ Paypal. 12:13. 11.7 ทด...
# 6    สร้าง RESTful API ด้วย Node.js (Express) และ M...
# 7    Cloud Computing หรือ การประมวลผลแบบกลุ่มเมฆ คื...
# 8    เรียนรู้เรื่องภัยคุกคามทางไซเบอร์ประเภทต่าง ๆ ...
# 9    ... วิทยากรเปิดสอนหลักสูตร Easy Android Progra...
# 10
# 11
# 12   สอนการทำ Data Analytics เริ่มจากศูนย์ จนสามารถ...
# 13   การสร้างคลังข้อมูล หรือ Data Warehouse ได้เกิด...
# 14   การจัดคลังข้อมูลเพื่อการตัดสินใจขององค์กร | Da...
# 15   ฉลาดด้วยข้อมูล ใครๆ ก็ทำได้ (คลังข้อมูลและการท...
# 16   Chapter 2: Data Warehouse. 2.1 นิยามและแนวคิดข...
# 17   เน้นการปูพื้นฐานการใช้ SAS และครอบคลุมเนื้อหาส...
# 18   วิชาคณิตศาสตร์เป็นวิชาที่เป็นรากฐานของหลายๆ วิ...
# 19   คอร์สนี้จะทำให้ผู้เรียนได้รู้เทคนิควิธีทำโฆษณา...
# 20   Google Adwords for Business คอร์สออนไลน์ เรียน...
# 21   สอนทำการตลาดออนไลน์บนกูเกิล (Google Marketing)...
# 22   สำหรับผู้ประกอบการ Mini SME/SME และผู้สนใจใช้ส...
# 23   คอร์สนี้จะได้เรียนรู้วิธีการทำโฆษณา Google Ads...
# 24   คอร์สออนไลน์นี้จะสอนจะวิธีการใช้งาน Google Adw...
# 25   สามารถไปสอบ Google Ads Search Certification ได...
# 26   "ติด 1-5 บนหน้าแรกของ Google คุณเองก็สามารถทำไ...
# 27   ติดอาวุธให้ร้านค้าออนไลน์ของคุณ สอนการใช้ Goog...
# 28   โฆษณา Google Ads คืออะไร? เริ่มต้นลงโฆษณาบน Go...
# 29   Google Analytics เป็นเครื่องมือสำหรับบันทึกข้อ...
# 30   คอร์สนี้จะทำให้ผู้เรียนได้รู้เทคนิคการใช้ Goog...
# 31   ไม่ว่าคุณจะเป็น เจ้าของเว็บไซต์, blogger, นักข...
# 32   ... เช่นผู้บริหาร หรือบุคคล พนักงานที่ต้องการล...
# 33   จากประสบการณ์ของผู้เชี่ยวชาญด้านการตลาดออนไลน์...
# 34   คอร์สนี้จะทำให้ผู้เรียนได้รู้เทคนิควิธีทำโฆษณา...
# 35   3.6 ทดสอบเพิ่มแผนที่ Google Maps ลงใน Post. 03...
# 36   ... of Google Analytics. ศุภณัฐ สุขโข. รายละเอ...
# 37   ไม่รู้ว่า ลูกค้าเราอยู่ที่ไหน อะไรขายดีที่สุด ...
# 38   Google Ads Master Class. img. ศุภณัฐ สุขโข ......
# 39
# 40   Video 22: ใช้ Google Trends เพื่อดูว่าคนค้นหาอ...
# 41   2.4 Google Trends. 06:20. 2.5 FastWork. 05:47....
# 42   สร้างรายได้จาก Youtube ขึ้นสู้หน้าแรก Google. ...
# 43   พบกับวิทยากรมากความสามารถ ผู้เป็นนักธุรกิจ eCo...
# 44   Winning Product สินค้าดีมีชัยไปกว่าครึ่ง; แหล่...
# 45   Google Hits High on Trends in Web Advertising....
# 46   Sign in with Facebook Sign in with Google Sign...
# 47   บทที่ 9: กลยุทธ์การทำกำไรในตลาดเหรียญคริปโต ตา...
# 48   Top 10 Trends เทรนด์ของธุรกิจรวมทั้งเทคโนโลยีแ...
# 49   ... Programming Language; อาจารย์พิเศษวิชา Pro...
# 50   คำอธิบายคอร์สออนไลน์ การใช้ภาษา PHP ในการพัฒนา...
# 51   ... Object-Oriented Programming หรือเรียกสั้น ...
# 52   ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 53   PHP Programming (The Basic). อธิภัทร หิรัญอดิศ...
# 54   Basic JavaScript for Modern Developer เตรียมตั...
# 55   คอร์สนี้จะสอนการพัฒนาเว็บไซต์ด้วยการ Coding (H...
# 56   สร้าง Web Application ด้วยภาษา Java. ธีระยุทธ ...
# 57   -ปัจจุบันเป็นวิทยากรสอน Microsoft Office (Powe...
# 58   ประกาศนียบัตร Big Data Programming with Hadoop...
# 59   เน้นการปูพื้นฐานการใช้ SAS และครอบคลุมเนื้อหาส...
# 60   Decision Tree & Random Forest เรียนทฤษฎี เขียน...
# 61   Web Programming จัดเต็มเน้นลงมือ! นคร สินผดุง....
# 62   Web Programming จัดเต็มเน้นลงมือ! นคร สินผดุง....
# 63   เรียนรู้ การทดสอบ iOS และ Android Application ...
# 64   บทที่ 4 เริ่มต้นการเขียนโปรแกรม Automate test ...
# 65   เรียนรู้ การทดสอบ Web, Mobile application และ ...
# 66   เรียนรู้การทดสอบ Web Application อย่างง่าย และ...
# 67   เรียนรู้ การทดสอบ Web Application ระดับกลาง ด้...
# 68   ตอนที่ 40 การแสดง Unit test Report บน Jenkins....
# 69   Mobile App Testing ด้วย APPIUM และ Robot Frame...
# 70   Mobile App Testing ด้วย APPIUM และ Robot Frame...
# 71   Mobile App Testing ด้วย APPIUM และ Robot Frame...
# 72   ... ขั้นตอนหลักในการออกแบบด้วย Design thinking...
# 73
# 74   เรียนรู้หลักการบริหารโครงการอย่างมีประสิทธิภาพ...
# 75   เรียนคอร์สออนไลน์ ด้านการลงทุน พัฒนาตัวเอง ธุร...
# 76   หนังสือ PRIMAVERA P6 for Project Management จำ...
# 77   สมัครคอร์สนี้ ฟรี! หนังสือ PROJECT PLANNING & ...
# 78   Project Management for Non-Project Managers เข...
# 79   VP of Technology & Product Development ที่ Ski...
# 80   หนังสือ Cost Control Using Microsoft Project จ...
# 81   VP of Technology & Product Development ที่ Ski...
# 82   ตอนที่ 7 วิธีการติดตั้งธีมที่ใช้งานใน Project ...
# 83   Project Management for Non-Project Managers เข...
# 84   เรียน Basic python programming จับมือทำตั้งแต่...
# 85   โปรแกรมไพทอนสำหรับวิทยาการข้อมูล | Python Prog...
# 86   24 ก.ย. 2020 ... ภาษา Python สำหรับวิทยาการข้อ...
# 87   “Coding for All : เรียนรู้ Python” เป็นคอร์สออ...
# 88   อยากทำงานด้าน Programming หรือ Up Skill เพิ่มเ...
# 89   ... Data analytics and machine learning with p...
# 90   ... Programming for Beginner. 15:31. 1.2 Softw...
# 91   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้ตั้งแต่ Pyth...
# 92   เรียนรู้เทคนิคการวิเคราะห์หุ้น จำลองพอร์ตการลง...
# 93   ... และโฟลเดอร์ ของ Windows ผ่าน Command Promp...
# 94   R Programming for Data Analysis. ... R เป็นเคร...
# 95   หากคุณคือคนที่ต้องจัดการกับข้อมูลจำนวนมหาศาล โ...
# 96   มาเรียน Data Science และ Data Analytics เบื้อง...
# 97   สอนการทำ Data Analytics เริ่มจากศูนย์ จนสามารถ...
# 98   เน้นการปูพื้นฐานการใช้ SAS และครอบคลุมเนื้อหาส...
# 99   3.8 R Program Descriptive. 23:10. Quiz 1. Quiz...
# 100  Introduction to R program. (51 นาที). Workshop...
# 101  Data Preparation. (16 นาที). Introduction to R...
# 102  วัตถุประสงค์. 1 . T o i n s t r u c t k n o w ...
# 103  ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 104  คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้การเขียน Swi...
# 105  iOS App Dev Using Swift: Foundation 1. ดร.ขจรศ...
# 106  ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 107  iOS App Dev Using Swift: Foundation 1. ดร.ขจรศ...
# 108  iOS App Dev Using Swift: Foundation 1. ดร.ขจรศ...
# 109  iOS App Dev Using Swift: Foundation 1. img. ดร...
# 110  ... Training ให้กับพนังงานขายในองค์กร โดยสอนเร...
# 111  เข้าใจหลักการทำงานของการใช้ภาษา Swift เกี่ยวกั...
# 108  https://skilllane.s3.amazonaws.com/courses/sha...
# 109  https://www.skilllane.com/images/logo/LogoFBSh...
# 110  https://skilllane.s3.amazonaws.com/courses/sha...
# 111  https://skilllane.s3.amazonaws.com/courses/sha...
# 112  https://skilllane.s3.amazonaws.com/courses/sha...
# 113  https://skilllane.s3.amazonaws.com/courses/sha...
# 114
# 115  https://skilllane.s3.amazonaws.com/courses/sha...
# 116  https://skilllane.s3.amazonaws.com/courses/sha...
#
#                                             meta_title  \
# 0    คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    คอร์สออนไลน์ Mobile App Testing ด้วย APPIUM แล...
# 3    คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4                  คอร์สออนไลน์ Jenkins CI/CD Workshop
# 5    คอร์สออนไลน์ สร้างร้านค้าออนไลน์ด้วย Woocommer...
# 6    คอร์สออนไลน์ บันได 3 ขั้น สู่การประยุกต์ใช้ Mi...
# 7
# 8    คอร์สปริญญาโทออนไลน์ Cyber Threats and Securit...
# 9    คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 10
# 11
# 12   คอร์สออนไลน์ ทำ Data Analytics ด้วย Power BI +...
# 13
# 14
# 15
# 16   คอร์สปริญญาโทออนไลน์ Business Intelligence ธุร...
# 17   คอร์สออนไลน์ เตรียมความพร้อมการจัดการและวิเครา...
# 18   CHULA MOOC | คอร์สเรียนออนไลน์ฟรี มหากาพย์ กลเ...
# 19   คอร์สออนไลน์ "Google Ads Master Class" | Skill...
# 20   คอร์สออนไลน์ เจาะลึกการทำโฆษณา Google Adwords ...
# 21   คอร์สออนไลน์ "ADWORDS, Simple But Effective" |...
# 22   คอร์สออนไลน์ฟรี "Banana Adwords 101 - การใช้งา...
# 23   คอร์สออนไลน์ "เจาะลึกการทำโฆษณา Google Search ...
# 24   คอร์สออนไลน์ Google Ads 2018 พื้นฐานและเทคนิคก...
# 25   คอร์สออนไลน์ "วุฒิบัตร Google Ads Search Certi...
# 26   คอร์สออนไลน์ "Banana Adwords 102 - Banana Adwo...
# 27            คอ์สออนไลน์ "ติดอันดับ Google ด้วยตนเอง"
# 28   ทำเว็บไซต์ให้ติดหน้าแรกบน Google ทันที ด้วย Go...
# 29   คอร์สออนไลน์ Google Analytics 101 สอนวิเคราะห์...
# 30   คอร์สออนไลน์ "The Master of Google Analytics" ...
# 31   คอร์สออนไลน์ เจาะลึก Google Analytics สำหรับมื...
# 32           Data analytics for Business | FutureSkill
# 33   คอร์สออนไลน์ "เริ่มด้วย Facebook แล้วบุกด้วย W...
# 34   คอร์สออนไลน์ "Google Ads Master Class" | Skill...
# 35   คอร์สออนไลน์ "WordPress 101 สำหรับผู้เริ่มต้น"...
# 36   คอร์สออนไลน์ "Zero to Hero มือใหม่ก็เรียนการตล...
# 37   คอร์สออนไลน์  Excel Business Data Analytics To...
# 38   SkillLane | คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวล...
# 39
# 40   คอร์สออนไลน์ "เริ่มด้วย Facebook แล้วบุกด้วย W...
# 41   คอร์สออนไลน์ "สูตรลับ การตลาดแบบมืออาชีพ PROFE...
# 42   สร้างรายได้จาก Youtube ขึ้นสู้หน้าแรก Google |...
# 43                คอร์สออนไลน์ "eCommerce Trends 2016"
# 44   Dropship ขายของออนไลน์รายได้หลักแสนต่อเดือน ทำ...
# 45   คอร์สออนไลน์ "เก่งภาษาแค่พลิกฝ่ามือ English fr...
# 46   คอร์สออนไลน์ "สุดยอดเคล็ดลับ รับรายได้หลักล้าน...
# 47   คอร์สออนไลน์ กลยุทธ์การทำกำไรในยุคดิจิตอลด้วย ...
# 48   คอร์สออนไลน์ Fast Forward Your Business | Skil...
# 49   คอร์สออนไลน์ PHP Programming (The Basic) | Ski...
# 50   คอร์สออนไลน์ "การเขียนโปรแกรมเชิงวัตถุด้วยภาษา...
# 51   คอร์สออนไลน์ฟรี เข้าใจ OOP ง่ายๆ ด้วยภาษา Java...
# 52   คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 53   คอร์สออนไลน์ Basic JavaScript for Modern Devel...
# 54   SkillLane | คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวล...
# 55   คอร์สออนไลน์ HTML5+CSS3 in 13 hours! พร้อมการใ...
# 56   คอร์สออนไลน์ "Python from Beginner to Expert ต...
# 57   คอร์สออนไลน์ เรียนวิธีใช้ Excel 2016 จัดการฐาน...
# 58   คอร์สปริญญาโทออนไลน์ Business Intelligence ธุร...
# 59   คอร์สออนไลน์ เตรียมความพร้อมการจัดการและวิเครา...
# 60   SkillLane | คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวล...
# 61   คอร์สออนไลน์ สร้างร้านค้าออนไลน์ด้วย WooCommer...
# 62   คอร์สออนไลน์ "พลังพยากรณ์ Python For Time Seri...
# 63   คอร์สออนไลน์ Mobile App Testing ด้วย APPIUM แล...
# 64   คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 65   คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 66   คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 67   คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 68                 คอร์สออนไลน์ Jenkins CI/CD Workshop
# 69   คอร์สออนไลน์ สร้างร้านค้าออนไลน์ด้วย Woocommer...
# 70   คอร์สออนไลน์ สร้างเว็บไซด์ด้วย ASP.NET Core MV...
# 71   คอร์สออนไลน์ "Coding for All: เรียนรู้ Python"...
# 72   UX UI Design ตั้งแต่เริ่มต้นจนออกแบบ Web App S...
# 73
# 74   คอร์สออนไลน์ "Project Management for Non-Proje...
# 75   SkillLane | คอร์สออนไลน์ สอนโดยผู้เชี่ยวชาญอัน...
# 76   คอร์สออนไลน์ "PRIMAVERA P6 เพื่อวางแผนและบริหา...
# 77   คอร์สออนไลน์ "การวางแผนและบริหารโครงการด้วย Mi...
# 78   SkillLane | คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวล...
# 79   คอร์สปริญญาโทออนไลน์ Agile Way of Working การท...
# 80   คอร์สออนไลน์ "วางแผนทรัพยากรและควบคุมต้นทุนด้ว...
# 81                                          seo title.
# 82   คอร์สออนไลน์ Alidropship + Theme FlatSome ทำเว...
# 83   คอร์สออนไลน์ "Retail Business Offline to Onlin...
# 84   UpSkill  Python Programming เส้นทางสู่  Develo...
# 85
# 86
# 87   คอร์สออนไลน์ "Coding for All: เรียนรู้ Python"...
# 88   Combo คอร์สเรียนสุดคุ้ม ! พัฒนาทักษะเพิ่มรายได...
# 89           Data analytics for Business | FutureSkill
# 90   คอร์สปริญญาโทออนไลน์ Python for Data Science ไ...
# 91   คอร์สออนไลน์ "Python from Beginner to Expert ต...
# 92   คอร์สออนไลน์ "เขียน Python เพิ่มโอกาสทำกำไรจาก...
# 93   คอร์สออนไลน์ "Programming Essentials for Data ...
# 94      R Programming for Data Analysis  | FutureSkill
# 95   คอร์สออนไลน์ Analytics 101 : โปรแกรม R สำหรับค...
# 96   Advanced Analytics 101: โปรแกรม R สำหรับคนใช้ ...
# 97   คอร์สออนไลน์ ทำ Data Analytics ด้วย Power BI +...
# 98   คอร์สออนไลน์ เตรียมความพร้อมการจัดการและวิเครา...
# 99   คอร์สปริญญาโทออนไลน์ Data Science Research Met...
# 100  วิเคราะห์ข้อมูลทางธุรกิจให้ตรงใจลูกค้าด้วย Bus...
# 101  วิเคราะห์ข้อมูลทางธุรกิจให้ตรงใจลูกค้าด้วย Bus...
# 102    CHULA MOOC | คอร์สเรียนออนไลน์ฟรี Survival Thai
# 103  คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 104  คอร์สออนไลน์ "iOS App Dev Using Swift: Foundat...
# 105  คอร์สออนไลน์ PHP Programming (The Basic) | Ski...
# 106  คอร์สออนไลน์ "Easy Android Programming เขียนแอ...
# 107  คอร์สออนไลน์ "สร้าง Auto report ส่งหัวหน้า ง่า...
# 108  คอร์สออนไลน์ "Coding for All: เรียนรู้ Python"...
# 109  SkillLane | คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวล...
# 110  คอร์สออนไลน์ "Excel Dashboard สำหรับวิเคราะห์ย...
# 111  คอร์สออนไลน์ iOS 12: เขียนแอพ iPhone จากดีไซน์...
# 112  คอร์สออนไลน์ "iOS App Dev Using Swift: Foundat...
# 113  คอร์สออนไลน์ โมดิฟาย WordPress Theme อย่างไรให...
# 114
# 115  คอร์สออนไลน์ สร้าง Web Application ด้วยภาษา Ja...
# 116  คอร์สออนไลน์ เขียนแอพ Android ด้วยภาษา Kotlin ...
#
#                                       meta_description  \
# 0    เรียนรู้การใช้ Katalon Studio เพื่อนำไปใช้ในกา...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    มาเรียนรู้วิธีการทดสอบเว็บด้วย Robot Framework...
# 4    เรียนรู้เกี่ยวกับการใช้งาน Jenkinsในการสร้าง C...
# 5    คอร์สสร้างร้านค้าออนไลน์ด้วย Woocommerce นี้ จ...
# 6    สอน Microsoft Access แบบลัด สั้น กระชับ ใช้ได้...
# 7
# 8    เรียนรู้เรื่องภัยคุกคามทางไซเบอร์ประเภทต่าง ๆ ...
# 9    ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 10
# 11
# 12   สอนการทำ Data Analytics เริ่มจากศูนย์ จนสามารถ...
# 13
# 14
# 15
# 16   สอนการทำ Business Intelligence เพื่อเปลี่ยนธุร...
# 17   เน้นการปูพื้นฐานการใช้ SAS และครอบคลุมเนื้อหาส...
# 18   วิชาคณิตศาสตร์เป็นวิชาที่เป็นรากฐานของหลายๆ วิ...
# 19   คอร์สนี้จะทำให้ผู้เรียนได้รู้เทคนิควิธีทำโฆษณา...
# 20   Google Adwords for Business คอร์สออนไลน์ เรียน...
# 21   สอนทำการตลาดออนไลน์บนกูเกิล (Google Marketing)...
# 22   สำหรับผู้ประกอบการ Mini SME/SME และผู้สนใจใช้ส...
# 23   คอร์สนี้จะได้เรียนรู้วิธีการทำโฆษณา Google Ads...
# 24   คอร์สออนไลน์นี้จะสอนจะวิธีการใช้งาน Google Adw...
# 25   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้เทคนิคการตลา...
# 26   "ติด 1-5 บนหน้าแรกของ Google คุณเองก็สามารถทำไ...
# 27   ติดอาวุธให้ร้านค้าออนไลน์ของคุณ สอนการใช้ Goog...
# 28   เรียนทำเว็บไซต์ของคุณให้ติดหน้าแรก Google ทันท...
# 29   สอนตั้งแต่ระดับพื้นฐานจนถึงระดับแอดวานซ์ ไม่ว่...
# 30   คอร์สนี้จะทำให้ผู้เรียนได้รู้เทคนิคการใช้ Goog...
# 31   ไม่ว่าคุณจะเป็น เจ้าของเว็บไซต์, blogger, นักข...
# 32   คอร์สนี้จะช่วยให้คุณนำข้อมูลที่มีอยู่จำนวนมากม...
# 33   เรียนแบบ step-by-step วิธีสร้างโมเดลธุรกิจออนไ...
# 34   คอร์สนี้จะทำให้ผู้เรียนได้รู้เทคนิควิธีทำโฆษณา...
# 35   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้เทคนิคการสร้...
# 36   คอร์สนี้จะได้เรียนรู้ภาพรวมการตลาดออนไลน์ในประ...
# 37   ให้คุณสามารถวิเคราะห์ข้อมูลที่มีอยู่ ด้วย Exce...
# 38   SkillLane โรงเรียนออนไลน์สำหรับคนที่ต้องการควา...
# 39
# 40   เรียนแบบ step-by-step วิธีสร้างโมเดลธุรกิจออนไ...
# 41   มอบความรู้การตลาดพื้นฐานไปจนถึงใช้งานได้จริง ร...
# 42   สร้างรายได้จาก YouTube ขึ้นสู้หน้าแรก Google ส...
# 43   พบกับวิทยากรมากความสามารถ ผู้เป็นนักธุรกิจ eCo...
# 44   Dropship ขายของออนไลน์รายได้หลักแสนต่อเดือน ทำ...
# 45   คอร์สนี้จะได้เรียนรู้วิธีวิเคราะห์โครงสร้างภาษ...
# 46   สอนตั้งแต่พื้นฐานการเปิดร้าน Shopee ไปจนถึงบริ...
# 47   สอนเทคนิคการทำกำไรในตลาดเงินสกุลดิจิทัลแบบง่าย...
# 48   คอร์สที่คุณจะทำให้คุณเห็นวิธีเปลี่ยนโฉมหน้าการ...
# 49   คอร์สที่จะทำให้คุณเข้าใจหลักการการพัฒนา web ap...
# 50   ผู้เรียนจะเข้าใจการเขียนโปรแกรมเชิงวัตถุ (OOP)...
# 51   ในคอร์สนี้เราจะสร้างโปรเจ็กต์ขึ้นมาทั้งหมด 4 โ...
# 52   ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 53   ในคอร์สนี้เราจะได้เรียนเนื้อหา JavaScript ตั้ง...
# 54   SkillLane โรงเรียนออนไลน์สำหรับคนที่ต้องการควา...
# 55   คอร์สนี้จะสอนการพัฒนาเว็บไซต์ด้วยการ Coding (H...
# 56   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้ตั้งแต่ Pyth...
# 57   เรียนวิธีใช้โปรแกรม Excel จัดการฐานข้อมูลที่มี...
# 58   สอนการทำ Business Intelligence เพื่อเปลี่ยนธุร...
# 59   เน้นการปูพื้นฐานการใช้ SAS และครอบคลุมเนื้อหาส...
# 60   SkillLane โรงเรียนออนไลน์สำหรับคนที่ต้องการควา...
# 61   สอนอย่างละเอียดและเจาะลึกครอบคลุททุกการใช้งานข...
# 62   คอร์สนี้จะได้เรียนรู้การทำนายข้อมูลธุรกิจ, อุต...
# 63   เรียนรู้ การทดสอบ iOS และ Android Application ...
# 64   เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 65   เรียนรู้การใช้ Katalon Studio เพื่อนำไปใช้ในกา...
# 66   เรียนรู้การทดสอบ Web Application อย่างง่าย และ...
# 67   มาเรียนรู้วิธีการทดสอบเว็บด้วย Robot Framework...
# 68   เรียนรู้เกี่ยวกับการใช้งาน Jenkinsในการสร้าง C...
# 69   คอร์สสร้างร้านค้าออนไลน์ด้วย Woocommerce นี้ จ...
# 70   หลังจากที่เรียนจบ ผู้เรียนจะมีเว็บประเภทกระดาน...
# 71   รู้เทคนิคการเขียนโปรแกรม สามารถเขียนโปรแกรมเพื...
# 72   เริ่มเส้นทางนักออกแบบประสบการณ์ที่ดีกับคอร์สเร...
# 73
# 74   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้หลักการบริหา...
# 75   เรียนคอร์สออนไลน์ ด้านการลงทุน พัฒนาตัวเอง ธุร...
# 76   สอนการใช้ PRIMAVERA P6 เพื่อวางแผนและบริหารโคร...
# 77   สอนวิธีใช้โปรแกรม Microsoft Project เพื่อการวา...
# 78   SkillLane โรงเรียนออนไลน์สำหรับคนที่ต้องการควา...
# 79   เรียนรู้ถึงปรัชญาของการทำงานแบบ Agile อย่างเจา...
# 80   คอร์สนี้จะได้เรียนรู้การใช้ Microsoft Project ...
# 81                                           seo desc.
# 82   สอนใช้งาน Alidropship + Theme FlatSome เพื่อทำ...
# 83   คอร์สออนไลน์นี้เป็นวีดีโอบรรยายที่พาผู้ค้าปลีก...
# 84   เรียน Basic python programming จับมือทำตั้งแต่...
# 85
# 86
# 87   รู้เทคนิคการเขียนโปรแกรม สามารถเขียนโปรแกรมเพื...
# 88   อยากทำงานด้าน Programming หรือ Up Skill เพิ่มเ...
# 89   คอร์สนี้จะช่วยให้คุณนำข้อมูลที่มีอยู่จำนวนมากม...
# 90   สอนการเขียนโปรแกรมภาษา Python เพื่อใช้สำหรับงา...
# 91   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้ตั้งแต่ Pyth...
# 92   เรียนรู้เทคนิคการวิเคราะห์หุ้น จำลองพอร์ตการลง...
# 93   คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้การจัดการข้อ...
# 94                     R Programming for Data Analysis
# 95   หากคุณคือคนที่ต้องจัดการกับข้อมูลจำนวนมหาศาล โ...
# 96   มาเรียน Data Science และ Data Analytics เบื้อง...
# 97   สอนการทำ Data Analytics เริ่มจากศูนย์ จนสามารถ...
# 98   เน้นการปูพื้นฐานการใช้ SAS และครอบคลุมเนื้อหาส...
# 99   เรียนรู้การวิเคราะห์ข้อมูลในรูปแบบต่างๆ โดยเฉพ...
# 100  สามารถทำ Predictive Model เพื่อตอบโจทย์ Busine...
# 101  สามารถทำ Predictive Model เพื่อตอบโจทย์ Busine...
# 102  ‘Survival Thai’ online course provides you les...
# 103  ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 104  คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้การเขียน Swi...
# 105  คอร์สที่จะทำให้คุณเข้าใจหลักการการพัฒนา web ap...
# 106  ไม่ต้องมีความรู้การเขียนโปรแกรมมาก่อน ก็เขียนแ...
# 107  ผู้เรียนจะได้รู้วิธีการทำรายงานอย่างมืออาชีพ เ...
# 108  รู้เทคนิคการเขียนโปรแกรม สามารถเขียนโปรแกรมเพื...
# 109  SkillLane โรงเรียนออนไลน์สำหรับคนที่ต้องการควา...
# 110  คอร์สนี้จะได้เรียนรู้เทคนิคการสร้าง Dashboard ...
# 111  คอร์สนี้รวบรวมเทคนิคที่สำคัญต่างๆ มากมายเพื่อใ...
# 112  คอร์สนี้จะทำให้ผู้เรียนได้เรียนรู้การเขียน Swi...
# 113  เรียนรู้วิธีการปรับแต่งธีมเวิร์ดเพรสด้วย Child...
# 114
# 115  คอร์สออนไลน์ เรียนได้ทุกที่ ทุกเวลา คลิ๊กเพื่อ...
# 116  ตะลุยเขียนแอพ Android 12 แอพ ด้วยภาษา Kotlin แ...
#
#                                               meta_url  \
# 0    https://www.skilllane.com/courses/automate-tes...
# 1    https://www.skilllane.com/courses/appium-autom...
# 2    https://www.skilllane.com/courses/app-testing-...
# 3    https://www.skilllane.com/courses/automated-te...
# 4    https://www.skilllane.com/courses/jenkins-cicd...
# 5    https://www.skilllane.com/courses/woocommerce-...
# 6    https://www.skilllane.com/courses/microsoft-ac...
# 7
# 8    https://www.skilllane.com/courses/tuxsa-Cyber-...
# 9    https://www.skilllane.com/courses/easy-android...
# 10
# 11
# 12   https://www.skilllane.com/courses/PowerBI-R-Fu...
# 13
# 14
# 15
# 16   https://www.skilllane.com/courses/tuxsa-busine...
# 17        https://www.skilllane.com/courses/SAS-Base-1
https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 94   https://firebasestorage.googleapis.com/v0/b/fu...
# 95   https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 96   https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 97   https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 98   https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 99   https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 100  https://firebasestorage.googleapis.com/v0/b/fu...
# 101  https://firebasestorage.googleapis.com/v0/b/fu...
# 102           https://mooc.chula.ac.th/favicon.png?v=2
# 103  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 104  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 105  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 106  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 107  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 108  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 109  https://www.skilllane.com/images/logo/LogoFBSh...      SkillLane
# 110  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 111  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 112  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 113  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 114
# 115  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 116  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
#
#        meta_type udemy_category udemy_instructor udemy_price
# 0        website
# 1        website
# 2        website
# 3        website
# 4        website
# 5        website
# 6        website
# 7
# 8        website
# 9        website
# 10
# 11
# 12       website
# 13
# 14
# 15
# 16       website
# 17       website
# 18       article
# 19       website
# 20       website
# 21       website
# 22       website
# 23       website
# 24       website
# 25       website
# 26       website
# 27       website
# 28   video.other
# 29       website
# 30       website
# 31       website
# 32   video.other
# 33       website
# 34       website
# 35       website
# 36       website
# 37       website
# 38       website
# 39
# 40       website
# 41       website
# 42   video.other
# 43       website
# 44   video.other
# 45       website
# 46       website
# 47       website
# 48       website
# 49       website
# 50       website
# 51       website
# 52       website
# 53       website
# 54       website
# 55       website
# 56       website
# 57       website
# 58       website
# 59       website
# 60       website
# 61       website
# 62       website
# 63       website
# 64       website
# 65       website
# 66       website
# 67       website
# 68       website
# 69       website
# 70       website
# 71       website
# 72   video.other
# 73
# 74       website
# 75       website
# 76       website
# 77       website
# 78       website
# 79       website
# 80       website
# 81       website
# 82       website
# 83       website
# 84   video.other
# 85
# 86
# 87       website
# 88   video.other
# 89   video.other
# 90       website
# 91       website
# 92       website
# 93       website
# 94   video.other
# 95       website
# 96       website
# 97       website
# 98       website
# 99       website
# 100  video.other
# 101  video.other
# 102      article
# 103      website
# 104      website
# 105      website
# 106      website
# 107      website
# 108      website
# 109      website
# 110      website
# 111      website
# 112      website
# 113      website
# 114
# 115      website
# 116      website

# %%
# res = {} 
# for key in keywords: 
#     for value in keywords_thai: 
#         res[key] = value 
#         keywords_thai.remove(value) 
#         break  
        
# df_thai = pd.DataFrame(res.items(), columns=['keyword_eng', 'keyword'])

# df_new = pd.merge(df_cse, df_thai, on='keyword')

# %%
# df_new.to_excel('exports/cse-keywords-thai.xlsx', index=False)
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(df_new)

# %% [markdown]
# ---

# %% [markdown]
# # udemy api request

# %%
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth("csRUo422lFAc78bHOPlbKsvK4mv4Lqar0vATRo0Z", "Cz2Zkw6vgQSPgQxxBtxT7QZuSy26s6VjNB1wRXiCsFIGcrKq5SbJl0kPXk5SxxXGYQLsmI4CHUOrea5aFl7tB7yNUKFOXdT0y009K2Dicju47BsqCIKiSD1qUv2fkWk9")

# %%
df_udemy = pd.DataFrame(columns = ['keyword', 'title', 'url', 'headline', 'price', 'img_url'])

# %%
for keyword in keywords:
    query = keyword
    url_ude = f"https://www.udemy.com/api-2.0/courses?page=1&page_size=5&search={query}"
    data_ude = requests.get(url_ude, auth=auth).json()

    response_items = data_ude.get("results")

    for i, response_item in enumerate(response_items, start=1):
        if i > 10: 
            break
            
        new_row = {'keyword':query, 
                   'title':response_item.get("title"), 
                   'url':"https://udemy.com" + response_item.get("url"), 
                   'headline':response_item.get("headline"),
                   'price':response_item.get("price"), 
                   'img_url':response_item.get("image_480x270")}
        df_udemy = df_udemy.append(new_row, ignore_index=True)

    time.sleep(1)

df_udemy.to_excel('exports/udemy-keywords.xlsx', index=False)

# %%
df_merge = pd.concat([df_cse, df_cse_en], ignore_index=True)

# %%
df_merge = df_merge.drop_duplicates(subset=['cse_url'])

# %%
df_merge.to_excel('exports/cse-keywords.xlsx', index=False)

# %%
# Out:
#          keyword                                          cse_title  \
# 0    API Testing  คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    API Testing  คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    API Testing  คอร์สออนไลน์ "Mobile App Testing ด้วย APPIUM แ...
# 3    API Testing  คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4    API Testing    คอร์สออนไลน์ Jenkins CI/CD Workshop | SkillLane
# ..           ...                                                ...
# 322          XML  Python Programming Bible | Networking, GUI, Em...
# 323          XML                XML from Beginner to Expert | Udemy
# 324          XML  Free C# Tutorial - C# .NET Database and XML Ap...
# 325          XML      XML - Master XML, XML Schema and XSLT | Udemy
# 326          XML  Technical Writing: How to Write Using DITA XML...
#
#                                        cse_description  \
# 0    เรียนรู้ การทดสอบ Web, Mobile application และ ...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    เรียนรู้ การทดสอบ Web Application ระดับกลาง ด้...
# 4    ตอนที่ 40 การแสดง Unit test Report บน Jenkins....
# ..                                                 ...
# 322  Python Programming Bible | Networking, GUI, Em...
# 323  You will discover how to create and read XML f...
# 324  Course content. Reviews. Instructors. In this ...
# 325  Learn XML, XML DTDs, Android Web service, Pars...
# 326  Mar 2, 2021 ... Do you want to learn how to wr...
#
#                                                cse_url  \
# 0    https://www.skilllane.com/courses/automate-tes...
# 1    https://www.skilllane.com/courses/appium-autom...
# 2    https://www.skilllane.com/courses/app-testing-...
# 3    https://www.skilllane.com/courses/automated-te...
# 4    https://www.skilllane.com/courses/jenkins-cicd...
# ..                                                 ...
# 322             https://www.udemy.com/course/pythonv3/
# 323  https://www.udemy.com/course/xml-from-beginner...
# 324  https://www.udemy.com/course/c-net-database-an...
# 325  https://www.udemy.com/course/xml-novice-to-ninja/
# 326  https://www.udemy.com/course/technical-writing...
#
#                                              cse_image  \
# 0    https://skilllane.s3.amazonaws.com/courses/sha...
# 1    https://skilllane.s3.amazonaws.com/courses/sha...
# 2    https://skilllane.s3.amazonaws.com/courses/sha...
# 3    https://skilllane.s3.amazonaws.com/courses/sha...
# 4    https://skilllane.s3.amazonaws.com/courses/sha...
# ..                                                 ...
# 322  https://img-b.udemycdn.com/course/480x270/1686...
# 323  https://img-a.udemycdn.com/course/480x270/5258...
# 324  https://img-a.udemycdn.com/course/480x270/2780...
# 325  https://img-a.udemycdn.com/course/480x270/1983...
# 326  https://img-a.udemycdn.com/course/480x270/1949...
#
#                                             meta_title  \
# 0    คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    คอร์สออนไลน์ Mobile App Testing ด้วย APPIUM แล...
# 3    คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4                  คอร์สออนไลน์ Jenkins CI/CD Workshop
# ..                                                 ...
# 322  Python Programming Bible | Networking, GUI, Em...
# 323                        XML from Beginner to Expert
# 324  Free C# Tutorial - C# .NET Database and XML Ap...
# 325              XML - Master XML, XML Schema and XSLT
# 326     Technical Writing: How to Write Using DITA XML
#
#                                       meta_description  \
# 0    เรียนรู้การใช้ Katalon Studio เพื่อนำไปใช้ในกา...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    มาเรียนรู้วิธีการทดสอบเว็บด้วย Robot Framework...
# 4    เรียนรู้เกี่ยวกับการใช้งาน Jenkinsในการสร้าง C...
# ..                                                 ...
# 322  Python 3 is one of the most popular programmin...
# 323  You will discover how to create and read XML f...
# 324     Implementing Real-World Examples - Free Course
# 325  Learn XML, XML DTDs, Android Web service, Pars...
# 326  How to Become a Modern and Successful Technica...
#
#                                               meta_url  \
# 0    https://www.skilllane.com/courses/automate-tes...
# 1    https://www.skilllane.com/courses/appium-autom...
# 2    https://www.skilllane.com/courses/app-testing-...
# 3    https://www.skilllane.com/courses/automated-te...
# 4    https://www.skilllane.com/courses/jenkins-cicd...
# ..                                                 ...
# 322             https://www.udemy.com/course/pythonv3/
# 323  https://www.udemy.com/course/xml-from-beginner...
# 324  https://www.udemy.com/course/c-net-database-an...
# 325  https://www.udemy.com/course/xml-novice-to-ninja/
# 326  https://www.udemy.com/course/technical-writing...
#
#                                             meta_image meta_site_name  \
# 0    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 1    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 2    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 3    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 4    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# ..                                                 ...            ...
# 322  https://img-b.udemycdn.com/course/480x270/1686...          Udemy
# 323  https://img-a.udemycdn.com/course/480x270/5258...          Udemy
# 324  https://img-a.udemycdn.com/course/480x270/2780...          Udemy
# 325  https://img-a.udemycdn.com/course/480x270/1983...          Udemy
# 326  https://img-a.udemycdn.com/course/480x270/1949...          Udemy
#
#             meta_type udemy_category  \
# 0             website
# 1             website
# 2             website
# 3             website
# 4             website
# ..                ...            ...
# 322  udemy_com:course    Development
# 323  udemy_com:course  IT & Software
# 324  udemy_com:course  IT & Software
# 325  udemy_com:course    Development
# 326  udemy_com:course    Development
#
#                                 udemy_instructor udemy_price
# 0
# 1
# 2
# 3
# 4
# ..                                           ...         ...
# 322  https://www.udemy.com/user/frahaanhussain2/     $199.99
# 323    https://www.udemy.com/user/danieleprotti/      $59.99
# 324  https://www.udemy.com/user/rick-phillips-6/        Free
# 325  https://www.udemy.com/user/premananda-suna/     $199.99
# 326   https://www.udemy.com/user/jordanstanchev/     $199.99
#
# [300 rows x 14 columns]
