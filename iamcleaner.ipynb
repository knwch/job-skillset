# %%
import numpy as np
import pandas as pd
import datetime
from dateutil.parser import parse
import tldextract

month_dict = {
    "ม.ค.": "Jan",
    "ก.พ.": "Feb",
    "มี.ค.": "Mar", 
    "เม.ย.": "Apr",
    "พ.ค.": "May",
    "มิ.ย.": "Jun",    
    "ก.ค.": "Jul",
    "ส.ค.": "Aug",
    "ก.ย.": "Sep",
    "ต.ค.": "Oct",
    "พ.ย.": "Nov",
    "ธ.ค.": "Dec",
}

# %%
dataframe = pd.read_excel('exports/cse-keywords.xlsx', index_col=0).reset_index()
dataframe.head()
# Out:
#        keyword                                          cse_title  \
# 0  API Testing  คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1  API Testing  คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2  API Testing  คอร์สออนไลน์ "Mobile App Testing ด้วย APPIUM แ...
# 3  API Testing  คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4  API Testing    คอร์สออนไลน์ Jenkins CI/CD Workshop | SkillLane
#
#                                      cse_description  \
# 0  เรียนรู้ การทดสอบ Web, Mobile application และ ...
# 1  เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2  เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3  เรียนรู้ การทดสอบ Web Application ระดับกลาง ด้...
# 4  ตอนที่ 40 การแสดง Unit test Report บน Jenkins....
#
#                                              cse_url  \
# 0  https://www.skilllane.com/courses/automate-tes...
# 1  https://www.skilllane.com/courses/appium-autom...
# 2  https://www.skilllane.com/courses/app-testing-...
# 3  https://www.skilllane.com/courses/automated-te...
# 4  https://www.skilllane.com/courses/jenkins-cicd...
#
#                                            cse_image  \
# 0  https://skilllane.s3.amazonaws.com/courses/sha...
# 1  https://skilllane.s3.amazonaws.com/courses/sha...
# 2  https://skilllane.s3.amazonaws.com/courses/sha...
# 3  https://skilllane.s3.amazonaws.com/courses/sha...
# 4  https://skilllane.s3.amazonaws.com/courses/sha...
#
#                                           meta_title  \
# 0  คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1  คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2  คอร์สออนไลน์ Mobile App Testing ด้วย APPIUM แล...
# 3  คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4                คอร์สออนไลน์ Jenkins CI/CD Workshop
#
#                                     meta_description  \
# 0  เรียนรู้การใช้ Katalon Studio เพื่อนำไปใช้ในกา...
# 1  เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2  เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3  มาเรียนรู้วิธีการทดสอบเว็บด้วย Robot Framework...
# 4  เรียนรู้เกี่ยวกับการใช้งาน Jenkinsในการสร้าง C...
#
#                                             meta_url  \
# 0  https://www.skilllane.com/courses/automate-tes...
# 1  https://www.skilllane.com/courses/appium-autom...
# 2  https://www.skilllane.com/courses/app-testing-...
# 3  https://www.skilllane.com/courses/automated-te...
# 4  https://www.skilllane.com/courses/jenkins-cicd...
#
#                                           meta_image meta_site_name meta_type  \
# 0  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane   website
# 1  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane   website
# 2  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane   website
# 3  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane   website
# 4  https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane   website
#
#   udemy_category udemy_instructor udemy_price
# 0            NaN              NaN         NaN
# 1            NaN              NaN         NaN
# 2            NaN              NaN         NaN
# 3            NaN              NaN         NaN
# 4            NaN              NaN         NaN

# %%
dataframe
# Out:
#          keyword                                          cse_title  \
# 0    API Testing  คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    API Testing  คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    API Testing  คอร์สออนไลน์ "Mobile App Testing ด้วย APPIUM แ...
# 3    API Testing  คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4    API Testing    คอร์สออนไลน์ Jenkins CI/CD Workshop | SkillLane
# ..           ...                                                ...
# 295          XML  Python Programming Bible | Networking, GUI, Em...
# 296          XML                XML from Beginner to Expert | Udemy
# 297          XML  Free C# Tutorial - C# .NET Database and XML Ap...
# 298          XML      XML - Master XML, XML Schema and XSLT | Udemy
# 299          XML  Technical Writing: How to Write Using DITA XML...
#
#                                        cse_description  \
# 0    เรียนรู้ การทดสอบ Web, Mobile application และ ...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    เรียนรู้ การทดสอบ Web Application ระดับกลาง ด้...
# 4    ตอนที่ 40 การแสดง Unit test Report บน Jenkins....
# ..                                                 ...
# 295  Python Programming Bible | Networking, GUI, Em...
# 296  You will discover how to create and read XML f...
# 297  Course content. Reviews. Instructors. In this ...
# 298  Learn XML, XML DTDs, Android Web service, Pars...
# 299  Mar 2, 2021 ... Do you want to learn how to wr...
#
#                                                cse_url  \
# 0    https://www.skilllane.com/courses/automate-tes...
# 1    https://www.skilllane.com/courses/appium-autom...
# 2    https://www.skilllane.com/courses/app-testing-...
# 3    https://www.skilllane.com/courses/automated-te...
# 4    https://www.skilllane.com/courses/jenkins-cicd...
# ..                                                 ...
# 295             https://www.udemy.com/course/pythonv3/
# 296  https://www.udemy.com/course/xml-from-beginner...
# 297  https://www.udemy.com/course/c-net-database-an...
# 298  https://www.udemy.com/course/xml-novice-to-ninja/
# 299  https://www.udemy.com/course/technical-writing...
#
#                                              cse_image  \
# 0    https://skilllane.s3.amazonaws.com/courses/sha...
# 1    https://skilllane.s3.amazonaws.com/courses/sha...
# 2    https://skilllane.s3.amazonaws.com/courses/sha...
# 3    https://skilllane.s3.amazonaws.com/courses/sha...
# 4    https://skilllane.s3.amazonaws.com/courses/sha...
# ..                                                 ...
# 295  https://img-b.udemycdn.com/course/480x270/1686...
# 296  https://img-a.udemycdn.com/course/480x270/5258...
# 297  https://img-a.udemycdn.com/course/480x270/2780...
# 298  https://img-a.udemycdn.com/course/480x270/1983...
# 299  https://img-a.udemycdn.com/course/480x270/1949...
#
#                                             meta_title  \
# 0    คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    คอร์สออนไลน์ Mobile App Testing ด้วย APPIUM แล...
# 3    คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4                  คอร์สออนไลน์ Jenkins CI/CD Workshop
# ..                                                 ...
# 295  Python Programming Bible | Networking, GUI, Em...
# 296                        XML from Beginner to Expert
# 297  Free C# Tutorial - C# .NET Database and XML Ap...
# 298              XML - Master XML, XML Schema and XSLT
# 299     Technical Writing: How to Write Using DITA XML
#
#                                       meta_description  \
# 0    เรียนรู้การใช้ Katalon Studio เพื่อนำไปใช้ในกา...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    มาเรียนรู้วิธีการทดสอบเว็บด้วย Robot Framework...
# 4    เรียนรู้เกี่ยวกับการใช้งาน Jenkinsในการสร้าง C...
# ..                                                 ...
# 295  Python 3 is one of the most popular programmin...
# 296  You will discover how to create and read XML f...
# 297     Implementing Real-World Examples - Free Course
# 298  Learn XML, XML DTDs, Android Web service, Pars...
# 299  How to Become a Modern and Successful Technica...
#
#                                               meta_url  \
# 0    https://www.skilllane.com/courses/automate-tes...
# 1    https://www.skilllane.com/courses/appium-autom...
# 2    https://www.skilllane.com/courses/app-testing-...
# 3    https://www.skilllane.com/courses/automated-te...
# 4    https://www.skilllane.com/courses/jenkins-cicd...
# ..                                                 ...
# 295             https://www.udemy.com/course/pythonv3/
# 296  https://www.udemy.com/course/xml-from-beginner...
# 297  https://www.udemy.com/course/c-net-database-an...
# 298  https://www.udemy.com/course/xml-novice-to-ninja/
# 299  https://www.udemy.com/course/technical-writing...
#
#                                             meta_image meta_site_name  \
# 0    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 1    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 2    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 3    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# 4    https://skilllane.s3.amazonaws.com/courses/sha...      SkillLane
# ..                                                 ...            ...
# 295  https://img-b.udemycdn.com/course/480x270/1686...          Udemy
# 296  https://img-a.udemycdn.com/course/480x270/5258...          Udemy
# 297  https://img-a.udemycdn.com/course/480x270/2780...          Udemy
# 298  https://img-a.udemycdn.com/course/480x270/1983...          Udemy
# 299  https://img-a.udemycdn.com/course/480x270/1949...          Udemy
#
#             meta_type udemy_category  \
# 0             website            NaN
# 1             website            NaN
# 2             website            NaN
# 3             website            NaN
# 4             website            NaN
# ..                ...            ...
# 295  udemy_com:course    Development
# 296  udemy_com:course  IT & Software
# 297  udemy_com:course  IT & Software
# 298  udemy_com:course    Development
# 299  udemy_com:course    Development
#
#                                 udemy_instructor udemy_price  \
# 0                                            NaN         NaN
# 1                                            NaN         NaN
# 2                                            NaN         NaN
# 3                                            NaN         NaN
# 4                                            NaN         NaN
# ..                                           ...         ...
# 295  https://www.udemy.com/user/frahaanhussain2/     $199.99
# 296    https://www.udemy.com/user/danieleprotti/      $59.99
# 297  https://www.udemy.com/user/rick-phillips-6/        Free
# 298  https://www.udemy.com/user/premananda-suna/     $199.99
# 299   https://www.udemy.com/user/jordanstanchev/     $199.99
#
#                                                  title  \
# 0    คอร์สออนไลน์ Automate Test Web, Mobile และ API...
# 1    คอร์สออนไลน์ Appium Automate Test Mobile Appli...
# 2    คอร์สออนไลน์ Mobile App Testing ด้วย APPIUM แล...
# 3    คอร์สออนไลน์ Web Automated Test ด้วย Robot Fra...
# 4                  คอร์สออนไลน์ Jenkins CI/CD Workshop
# ..                                                 ...
# 295  Python Programming Bible | Networking, GUI, Em...
# 296                        XML from Beginner to Expert
# 297  Free C# Tutorial - C# .NET Database and XML Ap...
# 298              XML - Master XML, XML Schema and XSLT
# 299     Technical Writing: How to Write Using DITA XML
#
#                                            description  \
# 0    เรียนรู้การใช้ Katalon Studio เพื่อนำไปใช้ในกา...
# 1    เรียนรู้การทำ Automate app บนมือถือด้วย Appium...
# 2    เรียนรู้ การทดสอบ iOS และ Android Application ...
# 3    มาเรียนรู้วิธีการทดสอบเว็บด้วย Robot Framework...
# 4    เรียนรู้เกี่ยวกับการใช้งาน Jenkinsในการสร้าง C...
# ..                                                 ...
# 295  Python 3 is one of the most popular programmin...
# 296  You will discover how to create and read XML f...
# 297     Implementing Real-World Examples - Free Course
# 298  Learn XML, XML DTDs, Android Web service, Pars...
# 299  How to Become a Modern and Successful Technica...
#
#                                                  image
# 0    https://skilllane.s3.amazonaws.com/courses/sha...
# 1    https://skilllane.s3.amazonaws.com/courses/sha...
# 2    https://skilllane.s3.amazonaws.com/courses/sha...
# 3    https://skilllane.s3.amazonaws.com/courses/sha...
# 4    https://skilllane.s3.amazonaws.com/courses/sha...
# ..                                                 ...
# 295  https://img-b.udemycdn.com/course/480x270/1686...
# 296  https://img-a.udemycdn.com/course/480x270/5258...
# 297  https://img-a.udemycdn.com/course/480x270/2780...
# 298  https://img-a.udemycdn.com/course/480x270/1983...
# 299  https://img-a.udemycdn.com/course/480x270/1949...
#
# [300 rows x 17 columns]

# %%
# for index in dataframe.index:

#     if pd.isnull(dataframe['title'][index]):
#        continue
#     else:        
#         if(pd.isnull(dataframe['meta_site_name'][index])):
#             dataframe['meta_site_name'][index] = tldextract.extract(dataframe['cse_url'][index]).domain.capitalize()
            
# dataframe.to_excel('exports/cse-keywords-cleaned.xlsx', index=False)

# %%
dataframe_new = dataframe

dataframe_new["title"] = np.nan
dataframe_new["description"] = np.nan
dataframe_new["image"] = np.nan
# dataframe_new["date"] = np.nan

# dataframe_new['meta_article_published_time'] = pd.to_datetime(dataframe_new['meta_article_published_time'], format='%Y-%m-%d %H:%M:%S', utc=True).dt.strftime('%d/%m/%Y')

# %%
def is_date(string, fuzzy=False):
    """
    Return whether the string can be interpreted as a date.

    :param string: str, string to check for date
    :param fuzzy: bool, ignore unknown tokens in string if True
    """
    try: 
        parse(string, fuzzy=fuzzy)
        return True

    except ValueError:
        return False
    
for index in dataframe_new.index:
    
    if pd.isnull(dataframe_new['cse_title'][index]):
       continue
    
    else:
    
        if(pd.isnull(dataframe_new['meta_title'][index])):
            dataframe_new['title'][index] = dataframe_new['cse_title'][index]
        else:
            dataframe_new['title'][index] = dataframe_new['meta_title'][index]

        if(pd.isnull(dataframe_new['meta_description'][index])):
            dataframe_new['description'][index] = dataframe_new['cse_description'][index]
        else:
            dataframe_new['description'][index] = dataframe_new['meta_description'][index]
            
        if(pd.isnull(dataframe_new['meta_site_name'][index])):
            dataframe_new['meta_site_name'][index] = tldextract.extract(dataframe_new['cse_url'][index]).domain.capitalize()

        if(pd.isnull(dataframe_new['meta_image'][index])):
            dataframe_new['image'][index] = dataframe_new['cse_image'][index]
        else:
            dataframe_new['image'][index] = dataframe_new['meta_image'][index]
            if(dataframe_new['image'][index][0] == '/' and dataframe_new['image'][index][1] == '/'):
                dataframe_new['image'][index] = dataframe_new['image'][index].replace("//", "https://")

#         if(pd.isnull(dataframe_new['meta_article_published_time'][index])):
#             date = dataframe_new['cse_description'][index].split(' ... ')[0]
#             for word, initial in month_dict.items():
#                 date = date.replace(word, initial)
#             if is_date(date):
#                 dataframe_new['date'][index] = date
#             else:
#                 dataframe_new['date'][index] = np.nan
#         else:
#             dataframe_new['date'][index] = dataframe_new['meta_article_published_time'][index]
        
# dataframe_new['date'] = pd.to_datetime(dataframe_new['date']).dt.strftime('%d/%m/%Y')
# Out:
# <ipython-input-5-dab1b0bcf848>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_new['title'][index] = dataframe_new['meta_title'][index]
# /usr/local/anaconda3/envs/ml101/lib/python3.9/site-packages/pandas/core/indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-5-dab1b0bcf848>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_new['description'][index] = dataframe_new['meta_description'][index]
# <ipython-input-5-dab1b0bcf848>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_new['image'][index] = dataframe_new['meta_image'][index]

# %%
# dataframe_export = dataframe_new[['keyword', 
# #                                 'keyword_th',
#                                 'title', 
#                                 'description', 
#                                 'cse_url', 
#                                 'image', 
#                                 'date', 
#                                 'meta_article_author',
#                                 'meta_author',
#                                 'meta_section',
#                                 'meta_tag',
#                                 'meta_site_name',
#                                 'meta_type']]

dataframe_export_course = dataframe_new[['keyword',
                                        'title', 
                                        'description', 
                                        'cse_url', 
                                        'image', 
                                        'meta_site_name',
                                        'meta_type',
                                        'udemy_category', 
                                        'udemy_instructor', 
                                        'udemy_price']]

# %%
dataframe_export.head()
# Out:
#                  keyword                                             title  \
# 0    Organization Acumen                                               NaN
# 1  Organizational Acumen                                               NaN
# 2                     OS                  How to ติดตั้ง Jenkins บน Mac OS
# 3                     OS  Things to know using type “Number” in JavaScript
# 4                     OS        Docker 101 | CH. 1 | Why Docker Container?
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2  ก่อนที่เราจะเริ่มติดตั้ง Jenkins ผมขออธิบาย To...
# 3  ประสบการณ์ครั้งนึงในชีวิตที่ ได้กดเครื่องคิดเล...
# 4  Docker พื้นฐาน บทที่ 1: ทำไมต้องเป็น Docker Co...
#
#                                              cse_url  \
# 0                                                NaN
# 1                                                NaN
# 2  https://medium.com/@theeratsiripongjinda/how-t...
# 3  https://medium.com/garkos/things-to-know-using...
# 4  https://medium.com/nutchalum.k/docker101-ch1-4...
#
#                                                image        date  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  https://miro.medium.com/max/1200/1*o6zHNMrX6M-...  31/07/2019
# 3  https://miro.medium.com/max/698/1*6JnMl0BSUSUc...  15/08/2017
# 4  https://miro.medium.com/max/802/1*-Vs0SIa-ctD8...  09/11/2017
#
#                         meta_article_author            meta_author  \
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2  https://medium.com/@theeratsiripongjinda  Theerat Siripongjinda
# 3                https://medium.com/@garkos                Gark Os
# 4           https://medium.com/@nutchalum.k   Nutchalum Kitpongsai
#
#   meta_section meta_tag meta_site_name meta_type
# 0          NaN      NaN            NaN       NaN
# 1          NaN      NaN            NaN       NaN
# 2          NaN      NaN         Medium   article
# 3          NaN      NaN         Medium   article
# 4          NaN      NaN         Medium   article

# %%
dataframe_export_course.to_excel('exports/cse-keywords-cleaned.xlsx', index=False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(dataframe_export)
# Out:
#                                            keyword  \
# 0                Activities and Activity Lifecycle
# 1           Agile Product Management Methodologies
# 2           Agile Product Management Methodologies
# 3           Agile Product Management Methodologies
# 4           Agile Product Management Methodologies
# 5           Agile Product Management Methodologies
# 6           Agile Product Management Methodologies
# 7           Agile Product Management Methodologies
# 8           Agile Product Management Methodologies
# 9           Agile Product Management Methodologies
# 10          Agile Product Management Methodologies
# 11                            Android Fundamentals
# 12                                             API
# 13                                             API
# 14                                             API
# 15                                             API
# 16                                             API
# 17                                             API
# 18                                             API
# 19                                             API
# 20                                             API
# 21                                             API
# 22                                       App Store
# 23                                       App Store
# 24                                       App Store
# 25                                       App Store
# 26                                       App Store
# 27                                       App Store
# 28                                       App Store
# 29                                       App Store
# 30                                       App Store
# 31                                       App Store
# 32                                  Authentication
# 33                                  Authentication
# 34                                  Authentication
# 35                                  Authentication
# 36                                  Authentication
# 37                                  Authentication
# 38                                  Authentication
# 39                                  Authentication
# 40                                  Authentication
# 41                                  Authentication
# 42                        Automation and Scripting
# 43                               Backup Procedures
# 44        Basic Hardware, Software and Programming
# 45        Basic Hardware, Software and Programming
# 46        Basic Hardware, Software and Programming
# 47        Basic Hardware, Software and Programming
# 48        Basic Hardware, Software and Programming
# 49        Basic Hardware, Software and Programming
# 50        Basic Hardware, Software and Programming
# 51        Basic Hardware, Software and Programming
# 52        Basic Hardware, Software and Programming
# 53        Basic Hardware, Software and Programming
# 54   Basic knowledge of Systems, Servers, Security
# 55   Basic knowledge of Systems, Servers, Security
# 56   Basic knowledge of Systems, Servers, Security
# 57   Basic knowledge of Systems, Servers, Security
# 58   Basic knowledge of Systems, Servers, Security
# 59   Basic knowledge of Systems, Servers, Security
# 60   Basic knowledge of Systems, Servers, Security
# 61   Basic knowledge of Systems, Servers, Security
# 62   Basic knowledge of Systems, Servers, Security
# 63   Basic knowledge of Systems, Servers, Security
# 64                                        Big Data
# 65                                        Big Data
# 66                                        Big Data
# 67                                        Big Data
# 68                                        Big Data
# 69                                        Big Data
# 70                                        Big Data
# 71                                        Big Data
# 72                                        Big Data
# 73                                        Big Data
# 74                              Build & Deployment
# 75                              Build & Deployment
# 76                              Build & Deployment
# 77                              Build & Deployment
# 78                              Build & Deployment
# 79                              Build & Deployment
# 80                              Build & Deployment
# 81                              Build & Deployment
# 82                              Build & Deployment
# 83                              Build & Deployment
# 84       Build Flexible Interfaces using Fragments
# 85                                     Build Tools
# 86                                     Build Tools
# 87                                     Build Tools
# 88                                     Build Tools
# 89                                     Build Tools
# 90                                     Build Tools
# 91                                     Build Tools
# 92                                     Build Tools
# 93                                     Build Tools
# 94                                     Build Tools
# 95                                 Business Acumen
# 96                                 Business Acumen
# 97                                 Business Acumen
# 98                                 Business Acumen
# 99                                 Business Acumen
# 100                                Business Acumen
# 101                                Business Acumen
# 102                                Business Acumen
# 103                                Business Acumen
# 104                                Business Acumen
# 105                                        Caching
# 106                                        Caching
# 107                                        Caching
# 108                                        Caching
# 109                                        Caching
# 110                                        Caching
# 111                                        Caching
# 112                                        Caching
# 113                                        Caching
# 114                                        Caching
# 115                             Caching Mechanisms
# 116                                          CI/CD
# 117                                          CI/CD
# 118                                          CI/CD
# 119                                          CI/CD
# 120                                          CI/CD
# 121                                          CI/CD
# 122                                          CI/CD
# 123                                          CI/CD
# 124                                          CI/CD
# 125                                          CI/CD
# 126                          Cloud Design Patterns
# 127                          Cloud Design Patterns
# 128                          Cloud Design Patterns
# 129                          Cloud Design Patterns
# 130                          Cloud Design Patterns
# 131                          Cloud Design Patterns
# 132                          Cloud Design Patterns
# 133                          Cloud Design Patterns
# 134                          Cloud Design Patterns
# 135                                Cloud Providers
# 136                                Cloud Providers
# 137                                Cloud Providers
# 138                                Cloud Providers
# 139                                Cloud Providers
# 140                                Cloud Providers
# 141                                Cloud Providers
# 142                                Cloud Providers
# 143                                Cloud Providers
# 144                                Cloud Providers
# 145                        Cloud Service Providers
# 146                        Cloud Service Providers
# 147                        Cloud Service Providers
# 148                        Cloud Service Providers
# 149                        Cloud Service Providers
# 150                        Cloud Service Providers
# 151                        Cloud Service Providers
# 152                        Cloud Service Providers
# 153                        Cloud Service Providers
# 154                        Cloud Service Providers
# 155                              Cluster Computing
# 156                              Cluster Computing
# 157                              Cluster Computing
# 158                              Cluster Computing
# 159                              Cluster Computing
# 160                              Cluster Computing
# 161                              Cluster Computing
# 162                              Cluster Computing
# 163                              Cluster Computing
# 164                              Cluster Computing
# 165                           Cocoa Design Pattern
# 166                            Computer Networking
# 167                            Computer Networking
# 168                            Computer Networking
# 169                            Computer Networking
# 170                            Computer Networking
# 171                            Computer Networking
# 172                            Computer Networking
# 173                            Computer Networking
# 174                            Computer Networking
# 175                            Computer Networking
# 176                              Conceptual Design
# 177                                    Concurrency
# 178                                    Concurrency
# 179                                    Concurrency
# 180                                    Concurrency
# 181                                    Concurrency
# 182                               Containarization
# 183                Containerization Virtualization
# 184                     Content Management Systems
# 185                     Content Management Systems
# 186                     Content Management Systems
# 187                     Content Management Systems
# 188                     Content Management Systems
# 189                     Content Management Systems
# 190                     Content Management Systems
# 191                     Content Management Systems
# 192                     Content Management Systems
# 193                     Content Management Systems
# 194                              Content Marketing
# 195                              Content Marketing
# 196                              Content Marketing
# 197                              Content Marketing
# 198                              Content Marketing
# 199                              Content Marketing
# 200                              Content Marketing
# 201                              Content Marketing
# 202                              Content Marketing
# 203                              Content Marketing
# 204                               Content Provider
# 205                               Content Provider
# 206                               Content Provider
# 207                               Content Provider
# 208                               Content Provider
# 209                               Content Provider
# 210                               Content Provider
# 211                               Content Provider
# 212                               Content Provider
# 213                               Content Provider
# 214                                            CSS
# 215                                            CSS
# 216                                            CSS
# 217                                            CSS
# 218                                            CSS
# 219                                            CSS
# 220                                            CSS
# 221                                            CSS
# 222                                            CSS
# 223                                            CSS
# 224                         Customer Understanding
# 225                         Customer Understanding
# 226                         Customer Understanding
# 227                         Customer Understanding
# 228                         Customer Understanding
# 229                         Customer Understanding
# 230                         Customer Understanding
# 231                         Customer Understanding
# 232                         Customer Understanding
# 233                         Customer Understanding
# 234                                  Data Analysis
# 235                                  Data Analysis
# 236                                  Data Analysis
# 237                                  Data Analysis
# 238                                  Data Analysis
# 239                                  Data Analysis
# 240                                  Data Analysis
# 241                                  Data Analysis
# 242                                  Data Analysis
# 243                                  Data Analysis
# 244                Data Analytics and Presentation
# 245                               Data Persistance
# 246                               Data Persistance
# 247                                Data Processing
# 248                                Data Processing
# 249                                Data Processing
# 250                                Data Processing
# 251                                Data Processing
# 252                                Data Processing
# 253                                Data Processing
# 254                                Data Processing
# 255                                Data Processing
# 256                                Data Processing
# 257                      Data Security and Privacy
# 258                      Data Security and Privacy
# 259                      Data Security and Privacy
# 260                      Data Security and Privacy
# 261                      Data Security and Privacy
# 262                      Data Security and Privacy
# 263                      Data Security and Privacy
# 264                      Data Security and Privacy
# 265                      Data Security and Privacy
# 266                 Data Structures and Algorithms
# 267                 Data Structures and Algorithms
# 268                 Data Structures and Algorithms
# 269                 Data Structures and Algorithms
# 270                 Data Structures and Algorithms
# 271                 Data Structures and Algorithms
# 272                 Data Structures and Algorithms
# 273                             Data Visualization
# 274                             Data Visualization
# 275                             Data Visualization
# 276                             Data Visualization
# 277                             Data Visualization
# 278                             Data Visualization
# 279                             Data Visualization
# 280                             Data Visualization
# 281                             Data Visualization
# 282                             Data Visualization
# 283           Data Visualizationa and Presentation
# 284                                Data warehouses
# 285                                Data warehouses
# 286                                Data warehouses
# 287                                Data warehouses
# 288                                Data warehouses
# 289                                Data warehouses
# 290                                Data warehouses
# 291                                Data warehouses
# 292                                Data warehouses
# 293                                Data warehouses
# 294                                 Data Wrangling
# 295                                 Data Wrangling
# 296                                 Data Wrangling
# 297                                 Data Wrangling
# 298                                 Data Wrangling
# 299                                       Database
# 300                                       Database
# 301                                       Database
# 302                                       Database
# 303                                       Database
# 304                                       Database
# 305                                       Database
# 306                    Database Management Systems
# 307                    Database Management Systems
# 308                    Database Management Systems
# 309                    Database Management Systems
# 310                    Database Management Systems
# 311                    Database Management Systems
# 312                    Database Management Systems
# 313                    Database Management Systems
# 314                    Database Management Systems
# 315                    Database Management Systems
# 316                  Database structure and theory
# 317                                      Debugging
# 318                                      Debugging
# 319                                      Debugging
# 320                                      Debugging
# 321                                      Debugging
# 322                                      Debugging
# 323                                      Debugging
# 324                                      Debugging
# 325                                      Debugging
# 326                                      Debugging
# 327                                  Deep Learning
# 328                                  Deep Learning
# 329                                  Deep Learning
# 330                                  Deep Learning
# 331                                  Deep Learning
# 332                                  Deep Learning
# 333                                  Deep Learning
# 334                                  Deep Learning
# 335                                  Deep Learning
# 336                                  Deep Learning
# 337                           Defect Tracking Tool
# 338                           Defect Tracking Tool
# 339                           Defect Tracking Tool
# 340                           Defect Tracking Tool
# 341                           Defect Tracking Tool
# 342                          Dependency Management
# 343                          Dependency Management
# 344                          Dependency Management
# 345                          Dependency Management
# 346                          Dependency Management
# 347                          Dependency Management
# 348                          Dependency Management
# 349                          Dependency Management
# 350                          Dependency Management
# 351                          Dependency Management
# 352              Design and Development Principles
# 353              Design and Development Principles
# 354              Design and Development Principles
# 355              Design and Development Principles
# 356              Design and Development Principles
# 357              Design and Development Principles
# 358              Design and Development Principles
# 359              Design and Development Principles
# 360              Design and Development Principles
# 361              Design and Development Principles
# 362                                Design Patterns
# 363                                Design Patterns
# 364                                Design Patterns
# 365                                Design Patterns
# 366                                Design Patterns
# 367                                Design Patterns
# 368                                Design Patterns
# 369                                Design Patterns
# 370                                Design Patterns
# 371                                Design Patterns
# 372                                   Design Tools
# 373                                   Design Tools
# 374                                   Design Tools
# 375                                   Design Tools
# 376                                   Design Tools
# 377                                   Design Tools
# 378                                   Design Tools
# 379                                   Design Tools
# 380                                   Design Tools
# 381                                   Design Tools
# 382               Desktop Applications Development
# 383               Desktop Applications Development
# 384               Desktop Applications Development
# 385               Desktop Applications Development
# 386               Desktop Applications Development
# 387               Desktop Applications Development
# 388               Desktop Applications Development
# 389               Desktop Applications Development
# 390               Desktop Applications Development
# 391               Desktop Applications Development
# 392                         Development Principles
# 393                         Development Principles
# 394                         Development Principles
# 395                         Development Principles
# 396                         Development Principles
# 397                         Development Principles
# 398                         Development Principles
# 399                         Development Principles
# 400                         Development Principles
# 401                         Development Principles
# 402                            Digital Advertising
# 403                            Digital Advertising
# 404                            Digital Advertising
# 405                            Digital Advertising
# 406                            Digital Advertising
# 407                            Digital Advertising
# 408                            Digital Advertising
# 409                            Digital Advertising
# 410                            Digital Advertising
# 411                            Digital Advertising
# 412        Disaster Recovery and Backup Procedures
# 413                           E-commerce Platforms
# 414                           E-commerce Platforms
# 415                           E-commerce Platforms
# 416                           E-commerce Platforms
# 417                           E-commerce Platforms
# 418                           E-commerce Platforms
# 419                           E-commerce Platforms
# 420                           E-commerce Platforms
# 421                           E-commerce Platforms
# 422                        Enterprise Architecture
# 423                        Enterprise Architecture
# 424                        Enterprise Architecture
# 425                        Enterprise Architecture
# 426                        Enterprise Architecture
# 427                                    ERP Systems
# 428                                    ERP Systems
# 429                                    ERP Systems
# 430                                    ERP Systems
# 431                                    ERP Systems
# 432                                    ERP Systems
# 433                                    ERP Systems
# 434                                    ERP Systems
# 435                                    ERP Systems
# 436                                    ERP Systems
# 437                           Front-end Frameworks
# 438                           Front-end Frameworks
# 439                           Front-end Frameworks
# 440                           Front-end Frameworks
# 441                           Front-end Frameworks
# 442                           Front-end Frameworks
# 443                           Front-end Frameworks
# 444                           Front-end Frameworks
# 445                           Front-end Frameworks
# 446                           Front-end Frameworks
# 447                                        GraphQL
# 448                                        GraphQL
# 449                                        GraphQL
# 450                                        GraphQL
# 451                                        GraphQL
# 452                                        GraphQL
# 453                                        GraphQL
# 454                                        GraphQL
# 455                                        GraphQL
# 456                                        GraphQL
# 457                    Handling App Configurations
# 458                    Handling App Configurations
# 459                    Handling App Configurations
# 460                    Handling App Configurations
# 461                    Handling App Configurations
# 462                    Handling App Configurations
# 463                    Handling App Configurations
# 464                    Handling App Configurations
# 465                                           HTML
# 466                                           HTML
# 467                                           HTML
# 468                                           HTML
# 469                                           HTML
# 470                                           HTML
# 471                                           HTML
# 472                                           HTML
# 473                                           HTML
# 474                                           HTML
# 475            Human Behaviour and Decision Making
# 476                 Identity and Access Management
# 477                 Identity and Access Management
# 478                         Infrastructure as Code
# 479                         Infrastructure as Code
# 480                         Infrastructure as Code
# 481                         Infrastructure as Code
# 482                         Infrastructure as Code
# 483                         Infrastructure as Code
# 484                         Infrastructure as Code
# 485                         Infrastructure as Code
# 486                         Infrastructure as Code
# 487                         Infrastructure as Code
# 488                                    Instruments
# 489                                    Instruments
# 490                                    Instruments
# 491                                    Instruments
# 492                                    Instruments
# 493                                    Instruments
# 494                                    Instruments
# 495                                    Instruments
# 496                                        Intents
# 497                                        Intents
# 498                                        Intents
# 499                                        Intents
# 500                       iOS programming language
# 501                       iOS programming language
# 502                       iOS programming language
# 503                       iOS programming language
# 504                       iOS programming language
# 505                       iOS programming language
# 506                       iOS programming language
# 507                       iOS programming language
# 508                       iOS programming language
# 509                       iOS programming language
# 510                               iOS Technologies
# 511                               iOS Technologies
# 512                               iOS Technologies
# 513                               iOS Technologies
# 514                               iOS Technologies
# 515                                    IT Security
# 516                                    IT Security
# 517                                    IT Security
# 518                                    IT Security
# 519                                    IT Security
# 520                                    IT Security
# 521                                    IT Security
# 522                                    IT Security
# 523                                    IT Security
# 524                                    IT Security
# 525                                     JavaScript
# 526                                     JavaScript
# 527                                     JavaScript
# 528                                     JavaScript
# 529                                     JavaScript
# 530                                     JavaScript
# 531                                     JavaScript
# 532                                     JavaScript
# 533                                     JavaScript
# 534                                     JavaScript
# 535                                 Linux Commands
# 536                                 Linux Commands
# 537                                 Linux Commands
# 538                                 Linux Commands
# 539                                 Linux Commands
# 540                                 Linux Commands
# 541                                 Linux Commands
# 542                                 Linux Commands
# 543                                 Linux Commands
# 544                                 Linux Commands
# 545                               Machine Learning
# 546                               Machine Learning
# 547                               Machine Learning
# 548                               Machine Learning
# 549                               Machine Learning
# 550                               Machine Learning
# 551                               Machine Learning
# 552                               Machine Learning
# 553                               Machine Learning
# 554                               Machine Learning
# 555                              Math Fundamentals
# 556                           Meeting Facilliation
# 557                               Message Broakers
# 558                               Message Broakers
# 559                               Message Broakers
# 560                               Message Broakers
# 561                               Message Broakers
# 562                               Message Broakers
# 563                               Message Broakers
# 564                                      Messaging
# 565                                      Messaging
# 566                                      Messaging
# 567                                      Messaging
# 568                                      Messaging
# 569                                      Messaging
# 570                                      Messaging
# 571                                      Messaging
# 572                                      Messaging
# 573                                      Messaging
# 574                Mobile Applications Development
# 575                Mobile Applications Development
# 576                Mobile Applications Development
# 577                Mobile Applications Development
# 578                Mobile Applications Development
# 579                Mobile Applications Development
# 580                Mobile Applications Development
# 581                Mobile Applications Development
# 582                Mobile Applications Development
# 583                Mobile Applications Development
# 584               Mobile Human Interface Guideline
# 585                      Monitoring Data Pipelines
# 586                      Monitoring Data Pipelines
# 587                            Motivational Acumen
# 588                                 Multithreading
# 589                          Network Configuration
# 590                          Network Configuration
# 591                          Network Configuration
# 592                          Network Configuration
# 593                          Network Configuration
# 594                          Network Configuration
# 595                          Network Configuration
# 596                          Network Configuration
# 597                          Network Configuration
# 598                          Network Configuration
# 599                            Network Programming
# 600                            Network Programming
# 601                            Network Programming
# 602                            Network Programming
# 603                            Network Programming
# 604                            Network Programming
# 605                            Network Programming
# 606                            Network Programming
# 607                            Network Programming
# 608                            Network Programming
# 609                Network, Security and Protocols
# 610                Network, Security and Protocols
# 611                Network, Security and Protocols
# 612                                     Networking
# 613                                     Networking
# 614                                     Networking
# 615                                     Networking
# 616                                     Networking
# 617                                     Networking
# 618                                     Networking
# 619                                     Networking
# 620                                     Networking
# 621                                     Networking
# 622                                 Object storage
# 623                                 Object storage
# 624                                 Object storage
# 625                                 Object storage
# 626                                 Object storage
# 627                                 Object storage
# 628                                 Object storage
# 629                                 Object storage
# 630                                 Object storage
# 631                                 Object storage
# 632                                  Orchestration
# 633                                  Orchestration
# 634                                  Orchestration
# 635                                  Orchestration
# 636                                  Orchestration
# 637                                  Orchestration
# 638                                  Orchestration
# 639                                  Orchestration
# 640                                  Orchestration
# 641                                  Orchestration
#
#                                                  title  \
# 0                                                  NaN
# 1    Day one of three days to delivering the knowle...
# 2    สรุปสิ่งที่ได้จากคลาส Agile Project Management...
# 3    [บันทึก] องค์ความรู้ และประสบการณ์ที่ส่งมอบใน ...
# 4    Day two of three days to delivering the knowle...
# 5                  UX จะเปล่งแสงในทีม Agile ได้อย่างไร
# 6    สรุปบทที่ 1 Why Plan จากหนังสือ Extreme Progra...
# 7               IoT x Agile in 3 days workshop at CAMT
# 8    อะไรบ้างที่ต้องทำเมื่อเราเป็น Software Tester ...
# 9    ควันหลงงาน Thailand Spin วันที่14 : Defining Y...
# 10                สิ่งที่ควรมองหาตอนทำ Agile Discovery
# 11                                                 NaN
# 12   ลองทำ Serverless WebSocket ด้วย AWS Lambda และ...
# 13              สร้าง Web Api ? ไม่เห็นต้อง Code เลย !
# 14        Stub Request/Response API ด้วย Golang Part#1
# 15          หัดเขียน API service ด้วย GraphQL (Part 1)
# 16   ประสบการณ์ฝึกเขียน API กับงานใหญ่ระดับมหาลัย K...
# 17   4 วิธีจัดการ Versioning และ Environment ของ AW...
# 18                   สร้างการแจ้งเตือนด้วย Line Notify
# 19          หัดเขียน API service ด้วย GraphQL (Part 2)
# 20                   สร้าง Mock จาก Example ใน Postman
# 21   When Unit testing is not enough. Do we need In...
# 22   เก็บภาษีดาวน์โหลด App จาก App Store และ Google...
# 23   ติดตั้งแอพและเครื่องมือจาก Macbook เครื่องเก่า...
# 24   วิเคราะห์ตลาดซอฟต์แวร์บน Play Store – Anuchit'...
# 25                 mapState กับ mapGetter ต่างกันยังไง
# 26   เก็บข้อมูลใน Redux Store ลงใน Local Storage ด้...
# 27                             ลองเล่น Vue.js กับ Vuex
# 28                                        - jobbkk.com
# 29   เดบิต ซื้อแอพ หักเงิน! ล้วงเรื่องลับ Apple กับ...
# 30                                            fastlane
# 31                 Next.Js 6 ทำ Redux ได้ง่ายขึ้นแล้ว!
# 32   ทำระบบ Login Facebook ง่ายขึ้นได้ด้วย Passport...
# 33      เก็บตกงาน eAuthentication Day – Anuchit's Blog
# 34                               Network at D-Day 2016
# 35                  มาเล่น NETPIE กัน – Anuchit's Blog
# 36                       มีดีอะไรใน Firebase Dev Day ?
# 37   Multi-Mechanize — web performance and load tes...
# 38   จัดการสิทธิ์การเข้าถึงด้วย Role Base Access Co...
# 39                                    Security Testing
# 40   มาลองใช้ Machine จัดการ Docker Host กัน – Anuc...
# 41   ใช้งาน Docker บน Google Container Engine – Anu...
# 42   กว่าจะมาเป็น TEST SCRIPT (ตอนที่ 2 : Test Desi...
# 43   ตัวอย่างเรซูเม่ภาษาอังกฤษ IT ระดับหัวหน้างาน |...
# 44   [บันทึกความเข้าใจ] การควบคุม Environment ของ S...
# 45          Software Verification and Validation (V&V)
# 46                              The First Computer Bug
# 47        การออกแบบ Scenario/Test case เริ่มตั้งแต่ไหน
# 48   [Conclusion] Chapter 5: Start Your Agile Proje...
# 49          Scaling Up กับ Scaling Out ต่างกันอย่างไร?
# 50   คนทำงานไอทีควรเร่งพัฒนาทักษะ รองรับการเติบโตธุ...
# 51                 เปรียบการสร้างเว็บ ดั่งการสร้างบ้าน
# 52   Cookbook สอน NodeJS กับ Express Ver. เด็ก Java...
# 53   งานโปรแกรมเมอร์ที่ตลาดต้องการมากหากอยากเป็นต้อ...
# 54        Mikrotik Config and Update for more security
# 55                                    Security Testing
# 56   มาติดตั้ง Linux Server ปลอดภัยกัน – Anuchit's ...
# 57   หนึ่งเดียวสำหรับตัววัดของ แอจไจล์ คือ Working ...
# 58                   การใช้ DNS-over-HTTPS บน Mikrotik
# 59   ความแตกต่างระหว่างงาน QA กับงาน QC ที่ต้องรู้ก...
# 60   จัดการสิทธิ์การเข้าถึงด้วย Role Base Access Co...
# 61   มาเล่น HA WordPress บน Rancher กัน – Anuchit's...
# 62   ตัวอย่างเรซูเม่ภาษาอังกฤษ IT สำหรับเด็กจบใหม่ ...
# 63                   มาเล่น OSSEC กัน – Anuchit's Blog
# 64   [DS — EP.5] Big Data มันใหญ่แค่ไหนกันนะ และเค้...
# 65   Data Scientist คืออะไร? รู้จักอาชีพตัวท็อปรายไ...
# 66   ทำความรู้จัก Data Analyst เบื้องหลังความสำเร็จ...
# 67   แนวโน้มระบบข้อมูลการตลาด : ระบบจัดข้อมูลการตลา...
# 68      [DS — EP.1] Data Scientist และเครื่องมือของเขา
# 69   [DS — EP.4] Data Visualization ไม่ได้ทำให้สวย ...
# 70   Skills ที่ต้องมีเพื่อตลาดงานด้าน AI ที่จะเพิ่ม...
# 71   งาน Logistics คืออะไรกันแน่ และมีประเภทไหนบ้าง...
# 72                                       8 For Success
# 73                                   รวมลิ้งสอน Docker
# 74   [Conclusion] Chapter 3: Build Teamwork with In...
# 75   [Conclusion] Chapter 2: Build the Cross-Functi...
# 76    มาสร้าง Docker image ด้วย multi-stage builds กัน
# 77   [Tutorial] เซ็ตอัพ Webpack และ React ตั้งแต่เร...
# 78   สร้าง Docker Image ผ่าน Build Service บน Docke...
# 79   แก้ปัญหา Invalid Build File Hash บน Cloud [Nex...
# 80   Build and Deploy ขึ้น Server โดยใช้ git hooks ...
# 81   [Nextjs] แก้ปัญหา Build แล้ว Error Allocation ...
# 82   บันทึกกันลืม Build Debian Package – Anuchit's ...
# 83   ตั้งค่า React Environment กับ Docker แบบ step-...
# 84                                                 NaN
# 85                          Dev Golang ยังไงให้ชีวิตดี
# 86       ลองเล่น vbuild อีกทางเลือกที่เร็วกว่า vue-cli
# 87   วิธีง่ายๆ สำหรับทำ AWS Lambda Layers ที่เป็น C...
# 88                                            fastlane
# 89       ลองเล่น Schema Stitching ใน graphql-tools 2.0
# 90                          Android Unit Testing Tools
# 91   Day two of three days to delivering the knowle...
# 92            เพิ่มประสิทธิภาพโค้ด React บน Production
# 93   มาลอง Code Coverage บน .Net Core 2+ ด้วย coverlet
# 94   ลองเล่น ProtoPie : Interactive Prototype Tool ...
# 95   การทำการตลาดระหว่างธุรกิจกับธุรกิจ:การทำการตลา...
# 96   Dealing with foreign-exchange risks: not as ha...
# 97   ควันหลงงาน Thailand Spin วันที่14 : Defining Y...
# 98   Multimedia | WordPress Bangkok CMS - Bangkok W...
# 99   When Unit testing is not enough. Do we need In...
# 100              เปิดศึกการใช้ Data อาวุธลับยุคดิจิทัล
# 101  [บันทึก] การเข้าร่วมในคลาส Microservice ของพี่...
# 102  Strategic Management Officer คือใคร | จ๊อบส์ดี...
# 103  [ExO — EP.5] บันได 12 ขั้นสู่การเป็น Exponenti...
# 104  ตัวอย่างเรซูเม่ Marketing ภาษาอังกฤษ | จ๊อบส์ด...
# 105                      บันทึกการใช้งาน Apollo Engine
# 106             Optimize GraphQL query ด้วย Dataloader
# 107           Apollo กับการ cache ที่ทำให้ผมต้องปวดหัว
# 108                       391 Commits = YWC#15 Website
# 109  รีวิว : Trello.com | ศิลป์ณวัช วรสิทธิพัฒน์ | ...
# 110           เพิ่มประสิทธิภาพโค้ด React บน Production
# 111                          PWA EP.2 — Service Worker
# 112  มาลองใช้ Firebase Remote Config ใน React Nativ...
# 113         ตามดู Zend Server Edition – Anuchit's Blog
# 114  ขยายความสามารถของ Refit ในการเรียกเว็บเซอร์วิส...
# 115                                                NaN
# 116  CI/CD with AWS Lambda (NodeJS Express) — Part ...
# 117  CI/CD with AWS Lambda (NodeJS Express) — Part ...
# 118  Jenkins x Bitbucket มาทำ CI/CD กันเถอะนายจ๋า (...
# 119  ทำ CI/CD บน Elastic Beanstalk ด้วย AWS CodePip...
# 120  ใช้งาน Docker Container กับ CI/CD – Anuchit's ...
# 121  Android x Jenkins ช่วยให้ชีวิตดีขึ้นยังไง ไหนเ...
# 122           Continuous delivery of valuable software
# 123                         Dev Golang ยังไงให้ชีวิตดี
# 124                   How to ติดตั้ง Jenkins บน Mac OS
# 125   มาสร้าง Docker image ด้วย multi-stage builds กัน
# 126  [เสพ-สรุป] ว่าด้วยเรื่อง Professionalism ตอนที...
# 127                 Design [ KMUTT Passport ] 1st time
# 128  [Test Automation] : มาเริ่มเตรียมความพร้อมสำหร...
# 129  IBM PureApp Pattern Bootcamp in Kuala Lumpur, ...
# 130  เข้าสู่ยุคของ Koin Dependency Injection framew...
# 131    การคิดเชิงระบบ-บทที่ II: การคิดเชิงระบบคืออะไร?
# 132   มาสร้าง Docker image ด้วย multi-stage builds กัน
# 133        [Event]: Mobile Defense-in-DEV #mobconf2019
# 134  [ExO — EP.3] SCALE: สมองซีกขวาของ Exponential ...
# 135  ย้าย Docker Container ข้าม Cloud Provider – An...
# 136                Standard และ Cloud – Anuchit's Blog
# 137  มาเล่น Google Cloud Launcher กัน – Anuchit's Blog
# 138                Journey to the cloud: The beginning
# 139  บริการจัดการ Cloud ของคุณด้วย Aeolus – Anuchit...
# 140     Journey to the cloud: Cloud Adoption Framework
# 141  ใช้งาน Docker บน Amazon Web Service – Anuchit'...
# 142                 มาเล่น CoreOS กัน – Anuchit's Blog
# 143  พัฒนา Web App บน Cloud ด้วย Zend Developer Clo...
# 144  ใช้งาน Docker บน Google Container Engine – Anu...
# 145  ย้าย Docker Container ข้าม Cloud Provider – An...
# 146                Standard และ Cloud – Anuchit's Blog
# 147  ใช้งาน Docker บน Amazon Web Service – Anuchit'...
# 148                Journey to the cloud: The beginning
# 149  มาเล่น Google Cloud Launcher กัน – Anuchit's Blog
# 150                 มาเล่น CoreOS กัน – Anuchit's Blog
# 151                   มาเล่น Juju กัน – Anuchit's Blog
# 152  พัฒนา Web App บน Cloud ด้วย Zend Developer Clo...
# 153                 Container Pattern – Anuchit's Blog
# 154  มาใช้ Rancher จัดการ Docker Container กัน – An...
# 155  ใช้งาน Docker บน Google Container Engine – Anu...
# 156    CoreOS Cluster บน DigitalOcean – Anuchit's Blog
# 157  มาเล่น Docker Machine + Swarm + Compose กัน – ...
# 158  สร้าง Cloud Infrastructure ด้วย OpenNebula ตอน...
# 159  เทรนด์เทคโนโลยี ซอฟต์แวร์โอเพนซอร์ส และ Cloud ...
# 160  มาเล่น High Availability MQTT Cluster ด้วย Doc...
# 161         Scaling Up กับ Scaling Out ต่างกันอย่างไร?
# 162         Scaling Docker ด้วย Swarm – Anuchit's Blog
# 163  มาเล่น HA WordPress บน Rancher กัน – Anuchit's...
# 164                  ใช้งาน Tutum กัน – Anuchit's Blog
# 165                                                NaN
# 166            ถึงเวลามูฟออนข้ามสายสู่ 19 งานแห่งอนาคต
# 167                  Intel HDMI Full Range RGB Setting
# 168           สายงานด้านไอที มีอะไรบ้างที่คุณควรรู้จัก
# 169  หางานไอที สายงานนี้มีดีอย่างไร ค้นหาคำตอบที่ทำ...
# 170      บริษัท ทางด่วนและรถไฟฟ้ากรุงเทพ จำกัด (มหาชน)
# 171  ต่อแลนคอมพิวเตอร์ มีขั้นตอนอย่างไร? เรามีวิธีง...
# 172  7 คำถามสัมภาษณ์งานและแนวทางการตอบ เพื่อทดสอบผู...
# 173  เก็บตกดูงาน Cloud Computing ที่สิงคโปร์ – Anuc...
# 174  P2P คืออะไร อีกหนึ่งรูปแบบการเชื่อมต่อแลนไร้สา...
# 175  ทำยังไงให้เล่น Game Online เร็วขึ้น !บทความนี้...
# 176                               UX ของ Chatbot ที่ดี
# 177        ระดมยิง Server ทดสอบความแรง ด้วย Bombardier
# 178  ฝึกเขียน Golang แล้วดียังไง ทำไม LINE MAN ถึงเ...
# 179  Training Program: Software Architectural Test ...
# 180                                         Clean Code
# 181              เปิดศึกการใช้ Data อาวุธลับยุคดิจิทัล
# 182                                                NaN
# 183         Docker 101 | CH. 1 | Why Docker Container?
# 184  Multimedia | WordPress Bangkok CMS - Bangkok W...
# 185             สร้าง Web Api ? ไม่เห็นต้อง Code เลย !
# 186  ความแตกต่างระหว่างงาน QA กับงาน QC ที่ต้องรู้ก...
# 187  ลักษณะและขอบเขตของงานการบริหารทรัพยากรมนุษย์ (...
# 188  งาน Logistics คืออะไรกันแน่ และมีประเภทไหนบ้าง...
# 189  ติด Alfresco Community 3.3 บน Ubuntu Server 10...
# 190          รวมงานจากบริษัทชั้นนำใน "ธุรกิจประกันภัย"
# 191                   มาเล่น Chef กัน – Anuchit's Blog
# 192  ทำความรู้จัก Data Analyst เบื้องหลังความสำเร็จ...
# 193  หาคนตรงงาน กับ jobsDB RMS Dashboard | จ๊อบส์ดี...
# 194  เทรนด์ Content Marketing ปี 2020 ที่นักการตลาด...
# 195    10 วิธีสร้าง Content ได้อย่างมีคุณค่าและน่าสนใจ
# 196  เส้นทางอาชีพ “Content Writer” และกลยุทธ์อัพเงิ...
# 197  5 ตำแหน่งงานการตลาดสำหรับเด็กจบใหม่ปี 2020 | จ...
# 198  Media Content คิดอย่างไรให้ปัง! ในวันที่ไอเดีย...
# 199  ทำความรู้จัก Data Analyst เบื้องหลังความสำเร็จ...
# 200  เทรนด์ Digital Marketing ล่าสุดในปี 2020 พร้อม...
# 201  หางานการตลาด ทั้ง 8 ประเภทที่ เด็กจบใหม่ ก็ทำไ...
# 202        บริษัท ออริจิ้น พร็อพเพอร์ตี้ จำกัด (มหาชน)
# 203  คำศัพท์พื้นฐานสู่การเป็นนักการตลาดดิจิทัล | จ๊...
# 204      เดาเทรน Chatbot , Apps on App , VR , AI First
# 205                    บริษัท เออาร์ไอพี จำกัด (มหาชน)
# 206  ย้าย Docker Container ข้าม Cloud Provider – An...
# 207  รวมตำแหน่งงาน “Account Executive” จากบริษัทชั้นนำ
# 208  ใช้งาน Docker บน Amazon Web Service – Anuchit'...
# 209  บริการจัดการ Cloud ของคุณด้วย Aeolus – Anuchit...
# 210                Standard และ Cloud – Anuchit's Blog
# 211  ใช้งาน Panamax จัดการ Docker Container – Anuch...
# 212  มาเล่น Google Cloud Launcher กัน – Anuchit's Blog
# 213                 Container Pattern – Anuchit's Blog
# 214  ลองใช้ styled-components สิ…แล้วคุณจะลืมการเขี...
# 215  มาทำความรู้จัก Debugging Style CSSใน React Native
# 216                       Creating our first HTML Page
# 217                เปรียบการสร้างเว็บ ดั่งการสร้างบ้าน
# 218                      ลองเล่น Styled-components กัน
# 219  CSS Tricks : การจัดรูปภาพให้สวยงาม โดยไม่ใช้ i...
# 220                    CODE IN THE DARK @ THiNKNET CNX
# 221                        Web Development Fundamental
# 222  [Tutorial] เซ็ตอัพ Webpack และ React ตั้งแต่เร...
# 223          “Webpack” ทำงานยังไง ? ไม่รู้ถือว่าบาป !!
# 224  [Conclusion] Chapter 4: Agile Requires Differe...
# 225                  หนังสือ Lean Customer Development
# 226                                         Casa Lapin
# ...
# 565                                   NaN                       Medium
# 566                                   NaN                       Medium
# 567                                   NaN                       Medium
# 568                                   NaN                       Medium
# 569                                   NaN                       Medium
# 570                                   NaN                       Medium
# 571                                   NaN                       Medium
# 572                                   NaN                       Medium
# 573                                   NaN                       Medium
# 574                                   NaN                   JOBBKK.COM
# 575                                   NaN                       Medium
# 576                                   NaN                       Medium
# 577                                   NaN                       Medium
# 578                                   NaN                       Medium
# 579                                   NaN                       Medium
# 580                                   NaN                       Medium
# 581                                   NaN                       Medium
# 582                                   NaN            Jobtopgun Article
# 583                          ทักษะงานไอที         จ๊อบส์ดีบี ประเทศไทย
# 584                                   NaN                          NaN
# 585                                   NaN                       Medium
# 586                                   NaN                       Medium
# 587                                   NaN                          NaN
# 588                                   NaN                       Medium
# 589                                   NaN                       Medium
# 590                                   NaN                       Medium
# 591                                   NaN                       Medium
# 592                                   NaN                       Medium
# 593                                   NaN                       Medium
# 594                                   NaN                       Medium
# 595                               คำศัพท์         จ๊อบส์ดีบี ประเทศไทย
# 596                                   NaN                       Medium
# 597                                   NaN                       Medium
# 598                                   NaN                       Medium
# 599                                   NaN                       Medium
# 600                                   NaN                       Medium
# 601                                   NaN                       Medium
# 602                                   NaN                       Medium
# 603                                   NaN                       Medium
# 604                                   NaN                       Medium
# 605                          ทักษะงานไอที         จ๊อบส์ดีบี ประเทศไทย
# 606                                   NaN                       Medium
# 607                                   NaN                       Medium
# 608                                   NaN                       Medium
# 609                                   NaN                       Medium
# 610                                   P2P         จ๊อบส์ดีบี ประเทศไทย
# 611                               คำศัพท์         จ๊อบส์ดีบี ประเทศไทย
# 612                                   NaN                  WorkVenture
# 613                                   NaN       Urban Affairs Magazine
# 614                                   NaN                  WorkVenture
# 615                                   NaN                       Medium
# 616                                   P2P         จ๊อบส์ดีบี ประเทศไทย
# 617                                   NaN            Jobtopgun Article
# 618                                   NaN       Urban Affairs Magazine
# 619                  Keyword เขียนเรซูเม่         จ๊อบส์ดีบี ประเทศไทย
# 620         ทำการตลาดด้วยเครื่องมือธุรกิจ         จ๊อบส์ดีบี ประเทศไทย
# 621                                   NaN            Jobtopgun Article
# 622                                   NaN                       Medium
# 623                                   NaN                       Medium
# 624                                   NaN                       Medium
# 625                                   NaN                       Medium
# 626                                   NaN                       Medium
# 627                                   NaN                       Medium
# 628                                   NaN                       Medium
# 629                                   NaN                       Medium
# 630                                   NaN                       Medium
# 631                                   NaN                       Medium
# 632                                   NaN                       Medium
# 633                                   NaN                       Medium
# 634                                   NaN                       Medium
# 635                                   NaN                       Medium
# 636                                   NaN                       Medium
# 637                                   NaN                       Medium
# 638                                   NaN                       Medium
# 639                                   NaN                       Medium
# 640                                   NaN                       Medium
# 641                                   NaN                       Medium
#
#     meta_type
# 0         NaN
# 1     article
# 2     article
# 3     article
# 4     article
# 5     article
# 6     article
# 7     article
# 8     article
# 9     article
# 10    article
# 11        NaN
# 12    article
# 13    article
# 14    article
# 15    article
# 16    article
# 17    article
# 18    article
# 19    article
# 20    article
# 21    article
# 22        NaN
# 23    article
# 24        NaN
# 25    article
# 26    article
# 27    article
# 28    website
# 29    article
# 30    article
# 31    article
# 32    article
# 33        NaN
# 34    article
# 35        NaN
# 36    article
# 37    article
# 38   websites
# 39    article
# 40        NaN
# 41        NaN
# 42    article
# 43    article
# 44    article
# 45    article
# 46    article
# 47    article
# 48    article
# 49    article
# 50    article
# 51    article
# 52    article
# 53    article
# 54    article
# 55    article
# 56        NaN
# 57    article
# 58    article
# 59    article
# 60   websites
# 61        NaN
# 62    article
# 63        NaN
# 64    article
# 65    article
# 66    article
# 67    article
# 68    article
# 69    article
# 70    article
# 71    article
# 72    article
# 73    article
# 74    article
# 75    article
# 76    article
# 77    article
# 78        NaN
# 79    article
# 80    article
# 81    article
# 82        NaN
# 83    article
# 84        NaN
# 85    article
# 86    article
# 87    article
# 88    article
# 89    article
# 90    article
# 91    article
# 92    article
# 93    article
# 94    article
# 95    article
# 96    article
# 97    article
# 98        NaN
# 99    article
# 100   article
# 101   article
# 102   article
# 103   article
# 104   article
# 105   article
# 106   article
# 107   article
# 108   website
# 109       NaN
# 110   article
# 111   article
# 112   article
# 113       NaN
# 114   article
# 115       NaN
# 116   article
# 117   article
# 118   article
# 119   article
# 120       NaN
# 121   article
# 122   article
# 123   article
# 124   article
# 125   article
# 126   article
# 127   article
# 128   article
# 129       NaN
# 130   article
# 131   article
# 132   article
# 133   article
# 134   article
# 135       NaN
# 136       NaN
# 137       NaN
# 138   article
# 139       NaN
# 140   article
# 141       NaN
# 142       NaN
# 143       NaN
# 144       NaN
# 145       NaN
# 146       NaN
# 147       NaN
# 148   article
# 149       NaN
# 150       NaN
# 151       NaN
# 152       NaN
# 153       NaN
# 154       NaN
# 155       NaN
# 156       NaN
# 157       NaN
# 158       NaN
# 159       NaN
# 160       NaN
# 161   article
# 162       NaN
# 163       NaN
# 164       NaN
# 165       NaN
# 166   article
# 167   article
# 168   article
# 169   article
# 170   article
# 171   article
# 172   article
# 173       NaN
# 174   article
# 175   article
# 176   article
# 177   article
# 178   article
# 179   article
# 180       NaN
# 181   article
# 182       NaN
# 183   article
# 184       NaN
# 185   article
# 186   article
# 187   article
# 188   article
# 189       NaN
# 190   article
# 191       NaN
# 192   article
# 193   article
# 194   article
# 195   article
# 196   article
# 197   article
# 198   article
# 199   article
# 200   article
# 201   article
# 202   article
# 203   article
# 204   article
# 205   article
# 206       NaN
# 207   article
# 208       NaN
# 209       NaN
# 210       NaN
# 211       NaN
# 212       NaN
# 213       NaN
# 214   website
# 215   article
# 216   article
# 217   article
# 218   article
# 219       NaN
# 220   article
# 221   article
# 222   article
# 223   article
# 224   article
# 225   article
# 226       NaN
# 227   article
# 228   article
# 229   article
# 230   article
# 231   article
# 232   article
# 233   article
# 234   article
# 235   article
# 236   article
# 237   article
# 238   article
# 239   article
# 240   article
# 241   article
# 242   article
# 243   article
# 244   article
# 245   article
# 246       NaN
# 247   article
# 248   article
# 249   article
# 250   article
# 251   article
# 252   article
# 253   article
# 254   article
# 255   article
# 256   article
# 257   article
# 258   article
# 259   article
# 260   article
# 261   article
# 262  websites
# 263   article
# 264   article
# 265   article
# 266   article
# 267   article
# 268   article
# 269   article
# 270   article
# 271   website
# 272   article
# 273   article
# 274   article
# 275   article
# 276   article
# 277   article
# 278   article
# 279   article
# 280   article
# 281   article
# 282   article
# 283   article
# 284   article
# 285   article
# 286       NaN
# 287   article
# 288   article
# 289   article
# 290   article
# 291   article
# 292   article
# 293       NaN
# 294   article
# 295   article
# 296   article
# 297   article
# 298   article
# 299   article
# 300   article
# 301   article
# 302   article
# 303   article
# 304   article
# 305   article
# 306   article
# 307   article
# 308   article
# 309   article
# 310   article
# 311   article
# 312   article
# 313   article
# 314   article
# 315   article
# 316   article
# 317   article
# 318       NaN
# 319   article
# 320       NaN
# 321   article
# 322   article
# 323   website
# 324   article
# 325   article
# 326       NaN
# 327       NaN
# 328   article
# 329   article
# 330   article
# 331   website
# 332   article
# 333   article
# 334   article
# 335   article
# 336   article
# 337   article
# 338   article
# 339   article
# 340   article
# 341   article
# 342   website
# 343   article
# 344   article
# 345   article
# 346       NaN
# 347   article
# 348       NaN
# 349   article
# 350   article
# 351      blog
# 352   article
# 353   article
# 354   article
# 355   article
# 356   article
# 357   article
# 358   article
# 359   article
# 360   article
# 361   article
# 362   article
# 363   article
# 364   article
# 365   article
# 366   article
# 367   article
# 368   article
# 369   article
# 370       NaN
# 371       NaN
# 372   article
# 373       NaN
# 374   article
# 375   article
# 376   article
# 377   article
# 378   article
# 379   article
# 380       NaN
# 381   article
# 382   article
# 383   article
# 384   article
# 385   article
# 386   article
# 387   article
# 388   article
# 389   article
# 390   article
# 391   article
# 392   article
# 393   article
# 394   article
# 395   article
# 396   article
# 397   article
# 398   article
# 399   article
# 400   article
# 401   article
# 402   article
# 403   article
# 404   article
# 405       NaN
# 406   article
# 407   article
# 408   article
# 409   article
# 410   article
# 411   article
# 412       NaN
# 413   article
# 414   article
# 415   article
# 416   article
# 417   article
# 418   article
# 419   article
# 420   article
# 421       NaN
# 422   article
# 423   article
# 424   article
# 425       NaN
# 426   article
# 427   article
# 428   article
# 429   article
# 430   article
# 431   article
# 432   article
# 433   article
# 434   article
# 435   article
# 436       NaN
# 437   website
# 438   article
# 439   website
# 440   article
# 441   article
# 442   article
# 443   article
# 444   article
# 445   article
# 446   article
# 447   article
# 448   article
# 449   article
# 450   article
# 451   article
# 452   article
# 453   article
# 454   article
# 455   article
# 456   article
# 457   article
# 458   article
# 459   article
# 460   article
# 461   article
# 462   article
# 463   article
# 464   article
# 465   article
# 466   article
# 467   article
# 468   article
# 469   website
# 470   article
# 471   article
# 472   article
# 473   article
# 474   article
# 475   article
# 476   article
# 477   article
# 478   article
# 479   article
# 480   article
# 481   article
# 482   article
# 483   article
# 484   article
# 485   article
# 486   article
# 487   article
# 488   article
# 489   article
# 490   article
# 491   article
# 492   article
# 493   article
# 494   article
# 495   article
# 496   article
# 497       NaN
# 498   article
# 499       NaN
# 500   article
# 501   article
# 502   article
# 503   article
# 504   article
# 505   article
# 506   article
# 507   article
# 508   article
# 509   article
# 510   website
# 511   article
# 512   article
# 513   article
# 514   article
# 515   article
# 516   article
# 517   article
# 518   article
# 519   article
# 520   article
# 521   article
# 522   article
# 523   article
# 524   article
# 525   article
# 526   article
# 527   article
# 528   article
# 529   article
# 530   article
# 531   article
# 532   article
# 533   website
# 534   article
# 535   article
# 536   article
# 537   article
# 538   article
# 539       NaN
# 540       NaN
# 541   article
# 542       NaN
# 543   article
# 544   article
# 545   article
# 546   article
# 547   article
# 548       NaN
# 549   article
# 550   article
# 551   article
# 552   article
# 553   article
# 554   article
# 555       NaN
# 556       NaN
# 557       NaN
# 558   article
# 559       NaN
# 560       NaN
# 561       NaN
# 562       NaN
# 563   article
# 564   article
# 565   article
# 566   article
# 567       NaN
# 568       NaN
# 569   article
# 570   article
# 571   article
# 572       NaN
# 573   article
# 574   article
# 575   article
# 576   article
# 577   article
# 578       NaN
# 579   article
# 580   article
# 581       NaN
# 582   article
# 583   article
# 584       NaN
# 585   article
# 586   article
# 587       NaN
# 588   article
# 589   article
# 590       NaN
# 591   article
# 592   article
# 593   article
# 594   article
# 595   article
# 596   article
# 597       NaN
# 598   article
# 599   article
# 600   article
# 601   article
# 602   article
# 603   article
# 604   article
# 605   article
# 606   article
# 607   article
# 608   article
# 609   article
# 610   article
# 611   article
# 612       NaN
# 613   article
# 614       NaN
# 615       NaN
# 616   article
# 617   article
# 618   article
# 619   article
# 620   article
# 621   article
# 622       NaN
# 623   article
# 624   article
# 625   website
# 626   article
# 627   article
# 628   article
# 629   article
# 630   article
# 631   article
# 632       NaN
# 633       NaN
# 634   article
# 635       NaN
# 636       NaN
# 637       NaN
# 638       NaN
# 639       NaN
# 640   article
# 641   article
